# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown --id 1aA9o8PJ-9gYAcLaaxLmXUrxlrHtArlrh -O Dataset_Misinfo_Fake.zip
# !gdown --id 1BhaOQU5wYDL8IxOzgvZM-IlgYfJf3HFD -O Dataset_Misinfo_True.zip

# !unzip Dataset_Misinfo_Fake.zip
# !unzip Dataset_Misinfo_True.zip
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1aA9o8PJ-9gYAcLaaxLmXUrxlrHtArlrh
# From (redirected): https://drive.google.com/uc?id=1aA9o8PJ-9gYAcLaaxLmXUrxlrHtArlrh&confirm=t&uuid=8fe92308-8733-4a7a-9be2-9688a235787d
# To: /content/Dataset_Misinfo_Fake.zip
# 100% 45.1M/45.1M [00:01<00:00, 26.8MB/s]
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1BhaOQU5wYDL8IxOzgvZM-IlgYfJf3HFD
# From (redirected): https://drive.google.com/uc?id=1BhaOQU5wYDL8IxOzgvZM-IlgYfJf3HFD&confirm=t&uuid=751abef0-206e-4afb-a773-06f05bef8b5c
# To: /content/Dataset_Misinfo_True.zip
# 100% 43.0M/43.0M [00:00<00:00, 44.3MB/s]
# Archive:  Dataset_Misinfo_Fake.zip
#   inflating: DataSet_Misinfo_FAKE.csv
# Archive:  Dataset_Misinfo_True.zip
#   inflating: DataSet_Misinfo_TRUE.csv

# %%
true_df = pd.read_csv('/content/DataSet_Misinfo_TRUE.csv')
fake_df = pd.read_csv('/content/DataSet_Misinfo_FAKE.csv')

# %%
true_df.head()
# Out:
#    Unnamed: 0                                               text
# 0           0  The head of a conservative Republican faction ...
# 1           1  Transgender people will be allowed for the fir...
# 2           2  The special counsel investigation of links bet...
# 3           3  Trump campaign adviser George Papadopoulos tol...
# 4           4  President Donald Trump called on the U.S. Post...

# %%
fake_df.head()
# Out:
#    Unnamed: 0                                               text
# 0           0  Donald Trump just couldn t wish all Americans ...
# 1           1  House Intelligence Committee Chairman Devin Nu...
# 2           2  On Friday, it was revealed that former Milwauk...
# 3           3  On Christmas day, Donald Trump announced that ...
# 4           4  Pope Francis used his annual Christmas Day mes...

# %%
# Add labels to indicate real and fake news
true_df['label'] = 1
fake_df['label'] = 0

# Concatenate both datasets
data = pd.concat([true_df, fake_df])
data.head()
# Out:
#    Unnamed: 0                                               text  label
# 0           0  The head of a conservative Republican faction ...      1
# 1           1  Transgender people will be allowed for the fir...      1
# 2           2  The special counsel investigation of links bet...      1
# 3           3  Trump campaign adviser George Papadopoulos tol...      1
# 4           4  President Donald Trump called on the U.S. Post...      1

# %%
print(data.shape)
print("\nMissing values:")
print(data.isnull().sum())
print("\nDuplicates count: ", data.duplicated(subset=['text']).sum())
# Out:
# (78617, 3)
#
# Missing values:
# Unnamed: 0     0
# text          29
# label          0
# dtype: int64
#
# Duplicates count:  10012

# %%
data.dropna(subset=['text'], inplace=True)
print(data.isnull().sum())

data.drop_duplicates(subset=['text'], inplace=True)
print(data.duplicated(subset=['text']).sum())
# Out:
# Unnamed: 0    0
# text          0
# label         0
# dtype: int64
# 0

# %%
data['id'] = np.arange(1, len(data) + 1)
data.head()
# Out:
#    Unnamed: 0                                               text  label  id
# 0           0  The head of a conservative Republican faction ...      1   1
# 1           1  Transgender people will be allowed for the fir...      1   2
# 2           2  The special counsel investigation of links bet...      1   3
# 3           3  Trump campaign adviser George Papadopoulos tol...      1   4
# 4           4  President Donald Trump called on the U.S. Post...      1   5

# %%
text_for_id = data[data['id'] == 68578]['text'].iloc[0]
text_for_id
# Out:
# 'NATO is developing a new plan of military operations in Europe that involves countering mythical "Russian aggression", the rapid deployment of troops from all over the continent and direct military support from the United States. Although Moscow has no plans to attack Europe, it is compelled to take defensive measures in light of NATO’s eastward expansion.'

# %% [markdown]
# ### EDA

# %%
import pandas as pd
import requests
import time
import json
from typing import Dict, Any, Optional, List
import os
import numpy as np
import random

MISTRAL_API_KEY: Optional[str] = 'MISTRAL_API_KEY'

if not MISTRAL_API_KEY:
    MISTRAL_API_KEY = os.getenv('MISTRAL_API_KEY')

API_MODEL_NAME: str = "pixtral-12b-2409"
API_ENDPOINT: str = "https://api.mistral.ai/v1/chat/completions"

IS_MOCK_MODE: bool = False
if not MISTRAL_API_KEY:
    IS_MOCK_MODE = True
    print(f"WARN: MISTRAL_API_KEY is not set. Running in MOCK MODE.")
    print(f"WARN: To use real API, set MISTRAL_API_KEY = 'your_actual_key' in the script")
    print(f"WARN: Or set environment variable: export MISTRAL_API_KEY='your_actual_key'")
else:
    print("INFO: Running with provided MISTRAL_API_KEY. Actual API calls will be made.")

PROCESSING_CHUNK_LOG_INTERVAL = 100
INITIAL_RETRY_DELAY = 10
MAX_RETRIES = 7
BASE_API_DELAY = 0

RATE_LIMIT_DELAY = 10
EXPONENTIAL_BACKOFF_MAX = 60
JITTER_RANGE = 0.05

output_column_name = 'subject_category'
ID_COLUMN_NAME = 'id'

def add_jitter(delay: float) -> float:
    """Add random jitter to delay to avoid synchronized requests"""
    jitter = delay * JITTER_RANGE * (2 * random.random() - 1)  # ±10% jitter
    return max(0.1, delay + jitter)

def get_prompt(article_text: str) -> str:
    processed_article_text: str = str(article_text).replace('"""', '\'\'\'')
    categories = [
        'politics', 'government', 'usNews', 'worldNews', 'middleEastNews',
        'technology', 'science', 'health', 'business', 'finance', 'sports',
        'entertainment', 'propaganda', 'socialIssues', 'environment',
        'education', 'crime', 'legal', 'other'
    ]
    category_list_string = ", ".join([f"'{cat}'" for cat in categories])
    return f"""Analyze the following news article snippet and classify its main subject into **exactly one** of the following categories:
{category_list_string}.

Choose the single most relevant category from the list. Your response should be ONLY the category name, nothing else.

Article Snippet:
\"\"\"
{processed_article_text}
\"\"\"

Category:"""

def get_subject_from_api(article_text: str, article_index_info: str) -> str:
    if not article_text.strip():
        return "N/A - Empty Input Text"

    if IS_MOCK_MODE:
        time.sleep(0.01)
        article_lower = article_text.lower()

        if any(word in article_lower for word in ['election', 'vote', 'candidate', 'republican', 'democrat', 'senate', 'congress', 'political']):
            return "politics"
        elif any(word in article_lower for word in ['government', 'federal', 'administration', 'policy', 'official', 'agency']):
            return "government"
        elif any(word in article_lower for word in ['united states', 'america', 'u.s.', 'american', 'domestic']):
            return "usNews"
        elif any(word in article_lower for word in ['international', 'world', 'global', 'foreign', 'country', 'nation']):
            return "worldNews"
        elif any(word in article_lower for word in ['middle east', 'israel', 'palestine', 'syria', 'iraq', 'iran']):
            return "middleEastNews"
        elif any(word in article_lower for word in ['technology', 'tech', 'software', 'computer', 'digital', 'ai', 'artificial intelligence']):
            return "technology"
        elif any(word in article_lower for word in ['science', 'research', 'study', 'scientist', 'discovery']):
            return "science"
        elif any(word in article_lower for word in ['health', 'medical', 'hospital', 'doctor', 'disease', 'vaccine']):
            return "health"
        elif any(word in article_lower for word in ['business', 'company', 'corporate', 'market', 'economy', 'economic']):
            return "business"
        elif any(word in article_lower for word in ['finance', 'financial', 'money', 'bank', 'stock', 'investment']):
            return "finance"
        elif any(word in article_lower for word in ['sports', 'game', 'team', 'player', 'championship', 'athletic']):
            return "sports"
        elif any(word in article_lower for word in ['entertainment', 'movie', 'music', 'celebrity', 'hollywood', 'film']):
            return "entertainment"
        elif any(word in article_lower for word in ['propaganda', 'misinformation', 'fake news']):
            return "propaganda"
        elif any(word in article_lower for word in ['social', 'community', 'rights', 'equality', 'discrimination', 'protest']):
            return "socialIssues"
        elif any(word in article_lower for word in ['environment', 'climate', 'pollution', 'green', 'sustainability']):
            return "environment"
        elif any(word in article_lower for word in ['education', 'school', 'university', 'student', 'teacher']):
            return "education"
        elif any(word in article_lower for word in ['crime', 'criminal', 'police', 'arrest', 'investigation']):
            return "crime"
        elif any(word in article_lower for word in ['legal', 'law', 'court', 'judge', 'lawsuit', 'attorney']):
            return "legal"
        else:
            return "other"

    prompt = get_prompt(article_text)

    payload: Dict[str, Any] = {
        "model": API_MODEL_NAME,
        "messages": [
            {
                "role": "user",
                "content": prompt
            }
        ],
        "temperature": 0.1,
        "max_tokens": 20,
        "top_p": 0.9
    }

    headers: Dict[str, str] = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {MISTRAL_API_KEY}'
    }

    current_retry_delay = INITIAL_RETRY_DELAY
    consecutive_rate_limits = 0

    for attempt in range(MAX_RETRIES):
        try:
            response = requests.post(API_ENDPOINT, json=payload, headers=headers, timeout=60)
            response.raise_for_status()

            consecutive_rate_limits = 0

            api_response_json: Dict[str, Any] = response.json()

            choices = api_response_json.get("choices")
            if choices and isinstance(choices, list) and len(choices) > 0:
                choice = choices[0]
                if choice and isinstance(choice, dict):
                    message = choice.get("message")
                    if message and isinstance(message, dict):
                        content = message.get("content")
                        if content and isinstance(content, str):
                            return content.strip()

            error_msg = f"Error: Could not parse category (Article: {article_index_info}). Unexpected API structure."
            print(f"WARN: {error_msg} Response: {json.dumps(api_response_json, indent=2)}")
            return error_msg

        except requests.exceptions.HTTPError as http_err:
            if http_err.response.status_code == 429:
                consecutive_rate_limits += 1

                rate_limit_delay = min(
                    RATE_LIMIT_DELAY * (2 ** consecutive_rate_limits),
                    EXPONENTIAL_BACKOFF_MAX
                )
                rate_limit_delay = add_jitter(rate_limit_delay)

                print(f"WARN: Rate limit hit for Article {article_index_info}. Attempt {attempt + 1}/{MAX_RETRIES}. "
                      f"Waiting {rate_limit_delay:.1f}s (consecutive rate limits: {consecutive_rate_limits})...")
                time.sleep(rate_limit_delay)

                if attempt == MAX_RETRIES - 1:
                    print(f"ERROR: Max retries reached for Article {article_index_info} due to rate limiting.")
                    return f"API Error: HTTP 429 Rate Limit (Max Retries)"

            elif http_err.response.status_code in [503, 500, 502]:  # Server errors
                print(f"WARN: HTTP {http_err.response.status_code} for Article {article_index_info}. "
                      f"Attempt {attempt + 1}/{MAX_RETRIES}. Retrying in {current_retry_delay}s...")
                time.sleep(add_jitter(current_retry_delay))
                current_retry_delay = min(current_retry_delay * 2, EXPONENTIAL_BACKOFF_MAX)

                if attempt == MAX_RETRIES - 1:
                    print(f"ERROR: Max retries reached for Article {article_index_info}. HTTP {http_err.response.status_code}.")
                    return f"API Error: HTTP {http_err.response.status_code} (Max Retries)"
            else:
                error_text = ""
                try:
                    error_text = http_err.response.text[:200]
                except:
                    error_text = "Could not read error response"
                print(f"ERROR: HTTPError {http_err.response.status_code} for Article {article_index_info}: {error_text}")
                return f"API Error: HTTP {http_err.response.status_code} (Critical)"

        except requests.exceptions.Timeout:
            print(f"WARN: Timeout for Article {article_index_info}. Attempt {attempt + 1}/{MAX_RETRIES}. "
                  f"Retrying in {current_retry_delay}s...")
            time.sleep(add_jitter(current_retry_delay))
            current_retry_delay = min(current_retry_delay * 2, EXPONENTIAL_BACKOFF_MAX)
            if attempt == MAX_RETRIES - 1:
                print(f"ERROR: Max retries reached for Article {article_index_info} due to Timeout.")
                return "API Error: Timeout (Max Retries)"

        except requests.exceptions.RequestException as req_err:
            print(f"ERROR: RequestException for Article {article_index_info}: {req_err}")
            return "API Error: Request Failed (Critical)"

        except Exception as e:
            print(f"ERROR: Unexpected error for Article {article_index_info}: {e} (Type: {type(e).__name__})")
            return f"Error: Unexpected ({type(e).__name__}) (Critical)"

    return "API Error: Max Retries Reached (Exited Loop) (Critical)"

def process_range(df_full: pd.DataFrame, start_row_idx: int, end_row_idx: int, start_id: int, end_id: int):
    """
    Processes a specific range of rows in the DataFrame.
    start_row_idx: 0-based integer start position (inclusive)
    end_row_idx: 0-based integer end position (exclusive)
    start_id: ID value of the first row to process
    end_id: ID value of the last row to process
    """
    if start_row_idx < 0 or end_row_idx > len(df_full) or start_row_idx >= end_row_idx:
        print(f"ERROR: Invalid row range. Start: {start_row_idx}, End: {end_row_idx}, Total Rows: {len(df_full)}")
        return

    df_slice = df_full.iloc[start_row_idx:end_row_idx].copy()

    if output_column_name not in df_slice.columns:
        df_slice[output_column_name] = pd.NA

    df_slice[output_column_name] = df_slice[output_column_name].apply(
        lambda x: pd.NA if isinstance(x, str) and
        (x.startswith("Error:") or x.startswith("API Error:") or x in ["N/A - Empty Text", "N/A - Empty Input Text"])
        else x
    )

    try:
        slice_text_col_idx = df_slice.columns.get_loc('text')
        slice_output_col_idx = df_slice.columns.get_loc(output_column_name)
        slice_id_col_idx = df_slice.columns.get_loc(ID_COLUMN_NAME) if ID_COLUMN_NAME in df_slice.columns else None
    except KeyError as e:
        print(f"ERROR: Required column missing in the slice: {e}")
        return

    num_rows_in_range = len(df_slice)
    print(f"\nProcessing range: IDs {start_id} to {end_id} (Total in this range: {num_rows_in_range})")

    stop_processing_flag = False
    processed_in_this_range = 0

    for i in range(num_rows_in_range):
        actual_df_index_label = df_slice.index[i]
        actual_df_row_number = start_row_idx + i + 1

        # Get actual ID value from the dataframe
        id_value = df_slice.iloc[i, slice_id_col_idx] if slice_id_col_idx is not None else "N/A"

        if (processed_in_this_range % PROCESSING_CHUNK_LOG_INTERVAL == 0) or PROCESSING_CHUNK_LOG_INTERVAL == 1:
            print(f"\nProcessing item {processed_in_this_range + 1}/{num_rows_in_range} in current range (ID: {id_value})...")

        current_category_scalar = df_slice.iloc[i, slice_output_col_idx]
        if pd.notna(current_category_scalar):
            print(f"ID {id_value}: Already processed with '{current_category_scalar}'. Skipping.")
            processed_in_this_range += 1
            continue

        article_text_scalar_val = df_slice.iloc[i, slice_text_col_idx]
        article_index_info = f"ID {id_value} (Row {actual_df_row_number}, Index Label: {actual_df_index_label})"

        if pd.isna(article_text_scalar_val) or not str(article_text_scalar_val).strip():
            print(f"{article_index_info}: Text is empty/NaN. Marking 'N/A - Empty Text'.")
            df_slice.iloc[i, slice_output_col_idx] = "N/A - Empty Text"
        else:
            extracted_category = get_subject_from_api(str(article_text_scalar_val), article_index_info)
            df_slice.iloc[i, slice_output_col_idx] = extracted_category
            print(f"{article_index_info}: Extracted: '{extracted_category}'")

            if "(Max Retries)" in extracted_category or "(Critical)" in extracted_category:
                print(f"CRITICAL ERROR on {article_index_info}. Stopping processing for this range.")
                stop_processing_flag = True

        processed_in_this_range += 1

        if not IS_MOCK_MODE and not stop_processing_flag:
            if not (isinstance(df_slice.iloc[i, slice_output_col_idx], str) and
                    df_slice.iloc[i, slice_output_col_idx].startswith("API Error:")):
                delay = add_jitter(BASE_API_DELAY)
                if delay > 0.1:
                    print(f"Waiting {delay:.1f}s before next request...")
                    time.sleep(delay)

        if stop_processing_flag:
            break

    range_output_filename = f"subjects_id_{start_id}_to_{end_id}.csv"
    try:
        columns_to_save = [ID_COLUMN_NAME, output_column_name]

        if ID_COLUMN_NAME not in df_slice.columns:
            print(f"ERROR: ID column '{ID_COLUMN_NAME}' not found in DataFrame slice.")
            return

        df_to_save = df_slice[columns_to_save].copy()

        df_to_save.to_csv(range_output_filename, index=False, encoding='utf-8')

        status_msg = "STOPPED_DUE_TO_ERROR" if stop_processing_flag else "COMPLETED_RANGE"
        print(f"\n--- Processing for ID range {start_id}-{end_id} {status_msg}. ---")
        print(f"{processed_in_this_range} rows attempted in this range. Results saved to '{range_output_filename}'")
        print(f"CSV file contains columns: {list(df_to_save.columns)}")
        print(f"ID range in saved file: {df_to_save[ID_COLUMN_NAME].min()} to {df_to_save[ID_COLUMN_NAME].max()}")

    except Exception as e:
        print(f"ERROR: Could not save results for ID range {start_id}-{end_id} to '{range_output_filename}': {e}")

if __name__ == "__main__":
    try:
        if 'data' not in locals() or not isinstance(data, pd.DataFrame):
            print("ERROR: DataFrame 'data' not found. Load it before running.")
            exit()
        print(f"INFO: Using pre-existing DataFrame 'data' with {len(data)} rows.")
    except Exception as e:
        print(f"ERROR: Could not access 'data' DataFrame: {e}")
        exit()

    if 'text' not in data.columns:
        print("ERROR: Your DataFrame 'data' must have a 'text' column.")
        exit()
    if ID_COLUMN_NAME and ID_COLUMN_NAME not in data.columns:
        print(f"ERROR: Specified ID_COLUMN_NAME '{ID_COLUMN_NAME}' not found in 'data' DataFrame.")
        print(f"Available columns: {data.columns.tolist()}")
        print("If you want to use the DataFrame index, set ID_COLUMN_NAME = None.")
        exit()

    try:
        start_id_value = 1

        max_id = len(data)
        if start_id_value < 1 or start_id_value > max_id:
            print(f"ERROR: ID value {start_id_value} is out of range.")
            print(f"Valid ID range: 1 to {max_id}")
            exit()

        manual_start_row_position = start_id_value - 1

        print(f"INFO: Requested start from ID value {start_id_value}, which is at DataFrame position {manual_start_row_position}.")

    except Exception as e:
        print(f"ERROR: Unexpected error when calculating start position by ID: {e}")
        exit()

    num_rows_to_process_manually = 68604
    manual_end_row_position = min(manual_start_row_position + num_rows_to_process_manually, len(data))

    start_id_actual = manual_start_row_position + 1
    end_id_actual = manual_end_row_position

    if manual_start_row_position >= len(data):
        print(f"INFO: Manual start row position {manual_start_row_position} is beyond the DataFrame length ({len(data)}). Nothing to process.")
    else:
        if IS_MOCK_MODE:
            print(f"INFO: Running in MOCK MODE with enhanced keyword matching...")
        else:
            print(f"INFO: Starting processing with Mistral API (Pixtral-12B)...")
            print(f"INFO: Base delay between requests: {BASE_API_DELAY}s (with jitter)")
            print(f"INFO: Rate limit retry delay starts at: {RATE_LIMIT_DELAY}s (exponential backoff)")

        print(f"INFO: Processing ID range {start_id_actual} to {end_id_actual}")
        process_range(data, manual_start_row_position, manual_end_row_position, start_id_actual, end_id_actual)

    print("\n--- Script Finished ---")
# Out:
# INFO: Running with provided MISTRAL_API_KEY. Actual API calls will be made.
# INFO: Using pre-existing DataFrame 'data' with 68604 rows.
# INFO: Requested start from ID value 7103, which is at DataFrame position 7102.
# INFO: Starting processing with Mistral API (Pixtral-12B)...
# INFO: Base delay between requests: 0s (with jitter)
# INFO: Rate limit retry delay starts at: 10s (exponential backoff)
# INFO: Processing ID range 7103 to 10000
#
# Processing range: IDs 7103 to 10000 (Total in this range: 2898)
#
# Processing item 1/2898 in current range (ID: 7103)...
# ID 7103 (Row 7103, Index Label: 7162): Extracted: 'politics'
# ID 7104 (Row 7104, Index Label: 7163): Extracted: 'politics'
# ID 7105 (Row 7105, Index Label: 7164): Extracted: 'politics'
# ID 7106 (Row 7106, Index Label: 7165): Extracted: 'politics'
# ID 7107 (Row 7107, Index Label: 7166): Extracted: 'politics'
# ID 7108 (Row 7108, Index Label: 7167): Extracted: 'legal'
# ID 7109 (Row 7109, Index Label: 7168): Extracted: 'politics'
# ID 7110 (Row 7110, Index Label: 7169): Extracted: 'politics'
# ID 7111 (Row 7111, Index Label: 7170): Extracted: 'politics'
# ID 7112 (Row 7112, Index Label: 7171): Extracted: 'politics'
# ID 7113 (Row 7113, Index Label: 7172): Extracted: 'politics'
# ID 7114 (Row 7114, Index Label: 7173): Extracted: 'usNews'
# ID 7115 (Row 7115, Index Label: 7174): Extracted: 'politics'
# ID 7116 (Row 7116, Index Label: 7175): Extracted: 'politics'
# ID 7117 (Row 7117, Index Label: 7176): Extracted: 'politics'
# ID 7118 (Row 7118, Index Label: 7177): Extracted: 'politics'
# ID 7119 (Row 7119, Index Label: 7178): Extracted: 'politics'
# ID 7120 (Row 7120, Index Label: 7179): Extracted: 'politics'
# ID 7121 (Row 7121, Index Label: 7180): Extracted: 'politics'
# ID 7122 (Row 7122, Index Label: 7181): Extracted: 'technology'
# ID 7123 (Row 7123, Index Label: 7182): Extracted: 'politics'
# ID 7124 (Row 7124, Index Label: 7183): Extracted: 'legal'
# ID 7125 (Row 7125, Index Label: 7184): Extracted: 'politics'
# ID 7126 (Row 7126, Index Label: 7185): Extracted: 'politics'
# ID 7127 (Row 7127, Index Label: 7186): Extracted: 'politics'
# ID 7128 (Row 7128, Index Label: 7187): Extracted: 'politics'
# ID 7129 (Row 7129, Index Label: 7188): Extracted: 'legal'
# ID 7130 (Row 7130, Index Label: 7189): Extracted: 'politics'
# ID 7131 (Row 7131, Index Label: 7190): Extracted: 'politics'
# ID 7132 (Row 7132, Index Label: 7191): Extracted: 'education'
# ID 7133 (Row 7133, Index Label: 7192): Extracted: 'politics'
# ID 7134 (Row 7134, Index Label: 7193): Extracted: 'politics'
# ID 7135 (Row 7135, Index Label: 7194): Extracted: 'politics'
# ID 7136 (Row 7136, Index Label: 7195): Extracted: 'government'
# ID 7137 (Row 7137, Index Label: 7196): Extracted: 'socialIssues'
# ID 7138 (Row 7138, Index Label: 7197): Extracted: 'politics'
# ID 7139 (Row 7139, Index Label: 7198): Extracted: 'politics'
# ID 7140 (Row 7140, Index Label: 7199): Extracted: 'politics'
# ID 7141 (Row 7141, Index Label: 7200): Extracted: 'worldNews'
# ID 7142 (Row 7142, Index Label: 7201): Extracted: 'politics'
# ID 7143 (Row 7143, Index Label: 7202): Extracted: 'politics'
# ID 7144 (Row 7144, Index Label: 7203): Extracted: 'politics'
# ID 7145 (Row 7145, Index Label: 7204): Extracted: 'worldNews'
# ID 7146 (Row 7146, Index Label: 7205): Extracted: 'entertainment'
# ID 7147 (Row 7147, Index Label: 7206): Extracted: 'politics'
# ID 7148 (Row 7148, Index Label: 7207): Extracted: 'politics'
# ID 7149 (Row 7149, Index Label: 7208): Extracted: 'government'
# WARN: Rate limit hit for Article ID 7150 (Row 7150, Index Label: 7209). Attempt 1/7. Waiting 20.5s (consecutive rate limits: 1)...
# ID 7150 (Row 7150, Index Label: 7209): Extracted: 'government'
# ID 7151 (Row 7151, Index Label: 7210): Extracted: 'politics'
# ID 7152 (Row 7152, Index Label: 7211): Extracted: 'worldNews'
# ID 7153 (Row 7153, Index Label: 7212): Extracted: 'politics'
# ID 7154 (Row 7154, Index Label: 7213): Extracted: 'politics'
# ID 7155 (Row 7155, Index Label: 7214): Extracted: 'politics'
# ID 7156 (Row 7156, Index Label: 7215): Extracted: 'politics'
# ID 7157 (Row 7157, Index Label: 7216): Extracted: 'politics'
# ID 7158 (Row 7158, Index Label: 7217): Extracted: 'politics'
# ID 7159 (Row 7159, Index Label: 7218): Extracted: 'middleEastNews'
# ID 7160 (Row 7160, Index Label: 7219): Extracted: 'politics'
# ID 7161 (Row 7161, Index Label: 7220): Extracted: 'politics'
# ID 7162 (Row 7162, Index Label: 7221): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7163 (Row 7163, Index Label: 7222). Attempt 1/7. Waiting 20.1s (consecutive rate limits: 1)...
# ID 7163 (Row 7163, Index Label: 7222): Extracted: 'politics'
# ID 7164 (Row 7164, Index Label: 7223): Extracted: 'politics'
# ID 7165 (Row 7165, Index Label: 7224): Extracted: 'cyber security'
# ID 7166 (Row 7166, Index Label: 7225): Extracted: 'middleEastNews'
# ID 7167 (Row 7167, Index Label: 7226): Extracted: 'education'
# ID 7168 (Row 7168, Index Label: 7227): Extracted: 'politics'
# ID 7169 (Row 7169, Index Label: 7228): Extracted: 'politics'
# ID 7170 (Row 7170, Index Label: 7229): Extracted: 'politics'
# ID 7171 (Row 7171, Index Label: 7230): Extracted: 'politics'
# ID 7172 (Row 7172, Index Label: 7231): Extracted: 'politics'
# ID 7173 (Row 7173, Index Label: 7232): Extracted: 'politics'
# ID 7174 (Row 7174, Index Label: 7233): Extracted: 'politics'
# ID 7175 (Row 7175, Index Label: 7234): Extracted: 'business'
# ID 7176 (Row 7176, Index Label: 7235): Extracted: 'government'
# ID 7177 (Row 7177, Index Label: 7236): Extracted: 'politics'
# ID 7178 (Row 7178, Index Label: 7237): Extracted: 'business'
# ID 7179 (Row 7179, Index Label: 7238): Extracted: 'worldNews'
# ID 7180 (Row 7180, Index Label: 7239): Extracted: 'politics'
# ID 7181 (Row 7181, Index Label: 7240): Extracted: 'politics'
# ID 7182 (Row 7182, Index Label: 7241): Extracted: 'government'
# ID 7183 (Row 7183, Index Label: 7242): Extracted: 'politics'
# ID 7184 (Row 7184, Index Label: 7243): Extracted: 'business'
# ID 7185 (Row 7185, Index Label: 7244): Extracted: 'politics'
# ID 7186 (Row 7186, Index Label: 7245): Extracted: 'middleEastNews'
# ID 7187 (Row 7187, Index Label: 7246): Extracted: 'politics'
# ID 7188 (Row 7188, Index Label: 7247): Extracted: 'politics'
# ID 7189 (Row 7189, Index Label: 7248): Extracted: 'politics'
# ID 7190 (Row 7190, Index Label: 7249): Extracted: 'politics'
# ID 7191 (Row 7191, Index Label: 7250): Extracted: 'politics'
# ID 7192 (Row 7192, Index Label: 7251): Extracted: 'politics'
# ID 7193 (Row 7193, Index Label: 7252): Extracted: 'worldNews'
# ID 7194 (Row 7194, Index Label: 7253): Extracted: 'politics'
# ID 7195 (Row 7195, Index Label: 7254): Extracted: 'politics'
# ID 7196 (Row 7196, Index Label: 7255): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7197 (Row 7197, Index Label: 7256). Attempt 1/7. Waiting 19.5s (consecutive rate limits: 1)...
# ID 7197 (Row 7197, Index Label: 7256): Extracted: 'politics'
# ID 7198 (Row 7198, Index Label: 7257): Extracted: 'finance'
# ID 7199 (Row 7199, Index Label: 7258): Extracted: 'environment'
# ID 7200 (Row 7200, Index Label: 7259): Extracted: 'worldNews'
# ID 7201 (Row 7201, Index Label: 7260): Extracted: 'politics'
# ID 7202 (Row 7202, Index Label: 7261): Extracted: 'politics'
#
# Processing item 101/2898 in current range (ID: 7203)...
# ID 7203 (Row 7203, Index Label: 7262): Extracted: 'politics'
# ID 7204 (Row 7204, Index Label: 7263): Extracted: 'socialIssues'
# ID 7205 (Row 7205, Index Label: 7264): Extracted: 'health'
# ID 7206 (Row 7206, Index Label: 7265): Extracted: 'socialIssues'
# ID 7207 (Row 7207, Index Label: 7266): Extracted: 'environment'
# ID 7208 (Row 7208, Index Label: 7267): Extracted: 'worldNews'
# ID 7209 (Row 7209, Index Label: 7268): Extracted: 'politics'
# ID 7210 (Row 7210, Index Label: 7269): Extracted: 'politics'
# ID 7211 (Row 7211, Index Label: 7270): Extracted: 'politics'
# ID 7212 (Row 7212, Index Label: 7271): Extracted: 'politics'
# ID 7213 (Row 7213, Index Label: 7272): Extracted: 'politics'
# ID 7214 (Row 7214, Index Label: 7273): Extracted: 'technology'
# ID 7215 (Row 7215, Index Label: 7274): Extracted: 'worldNews'
# ID 7216 (Row 7216, Index Label: 7275): Extracted: 'socialIssues'
# ID 7217 (Row 7217, Index Label: 7276): Extracted: 'politics'
# ID 7218 (Row 7218, Index Label: 7277): Extracted: 'politics'
# ID 7219 (Row 7219, Index Label: 7278): Extracted: 'politics'
# ID 7220 (Row 7220, Index Label: 7279): Extracted: 'politics'
# ID 7221 (Row 7221, Index Label: 7280): Extracted: 'politics'
# ID 7222 (Row 7222, Index Label: 7281): Extracted: 'worldNews'
# ID 7223 (Row 7223, Index Label: 7282): Extracted: 'politics'
# ID 7224 (Row 7224, Index Label: 7283): Extracted: 'politics'
# ID 7225 (Row 7225, Index Label: 7284): Extracted: 'finance'
# ID 7226 (Row 7226, Index Label: 7285): Extracted: 'finance'
# WARN: Rate limit hit for Article ID 7227 (Row 7227, Index Label: 7286). Attempt 1/7. Waiting 20.9s (consecutive rate limits: 1)...
# ID 7227 (Row 7227, Index Label: 7286): Extracted: 'politics'
# ID 7228 (Row 7228, Index Label: 7287): Extracted: 'politics'
# ID 7229 (Row 7229, Index Label: 7288): Extracted: 'politics'
# ID 7230 (Row 7230, Index Label: 7289): Extracted: 'politics'
# ID 7231 (Row 7231, Index Label: 7290): Extracted: 'politics'
# ID 7232 (Row 7232, Index Label: 7291): Extracted: 'politics'
# ID 7233 (Row 7233, Index Label: 7292): Extracted: 'politics'
# ID 7234 (Row 7234, Index Label: 7293): Extracted: 'politics'
# ID 7235 (Row 7235, Index Label: 7294): Extracted: 'politics'
# ID 7236 (Row 7236, Index Label: 7295): Extracted: 'politics'
# ID 7237 (Row 7237, Index Label: 7296): Extracted: 'politics'
# ID 7238 (Row 7238, Index Label: 7297): Extracted: 'politics'
# ID 7239 (Row 7239, Index Label: 7298): Extracted: 'education'
# ID 7240 (Row 7240, Index Label: 7299): Extracted: 'technology'
# ID 7241 (Row 7241, Index Label: 7300): Extracted: 'legal'
# ID 7242 (Row 7242, Index Label: 7301): Extracted: 'politics'
# ID 7243 (Row 7243, Index Label: 7302): Extracted: 'politics'
# ID 7244 (Row 7244, Index Label: 7303): Extracted: 'finance'
# ID 7245 (Row 7245, Index Label: 7304): Extracted: 'environment'
# ID 7246 (Row 7246, Index Label: 7305): Extracted: 'politics'
# ID 7247 (Row 7247, Index Label: 7306): Extracted: 'worldNews'
# ID 7248 (Row 7248, Index Label: 7307): Extracted: 'politics'
# ID 7249 (Row 7249, Index Label: 7308): Extracted: 'environment'
# ID 7250 (Row 7250, Index Label: 7309): Extracted: 'politics'
# ID 7251 (Row 7251, Index Label: 7310): Extracted: 'crime'
# WARN: Rate limit hit for Article ID 7252 (Row 7252, Index Label: 7311). Attempt 1/7. Waiting 21.0s (consecutive rate limits: 1)...
# ID 7252 (Row 7252, Index Label: 7311): Extracted: 'politics'
# ID 7253 (Row 7253, Index Label: 7312): Extracted: 'socialIssues'
# ID 7254 (Row 7254, Index Label: 7313): Extracted: 'politics'
# ID 7255 (Row 7255, Index Label: 7314): Extracted: 'politics'
# ID 7256 (Row 7256, Index Label: 7315): Extracted: 'politics'
# ID 7257 (Row 7257, Index Label: 7316): Extracted: 'politics'
# ID 7258 (Row 7258, Index Label: 7317): Extracted: 'health'
# ID 7259 (Row 7259, Index Label: 7318): Extracted: 'politics'
# ID 7260 (Row 7260, Index Label: 7319): Extracted: 'politics'
# ID 7261 (Row 7261, Index Label: 7320): Extracted: 'usNews'
# ID 7262 (Row 7262, Index Label: 7321): Extracted: 'politics'
# ID 7263 (Row 7263, Index Label: 7322): Extracted: 'crime'
# ID 7264 (Row 7264, Index Label: 7323): Extracted: 'politics'
# ID 7265 (Row 7265, Index Label: 7324): Extracted: 'politics'
# ID 7266 (Row 7266, Index Label: 7325): Extracted: 'health'
# ID 7267 (Row 7267, Index Label: 7326): Extracted: 'politics'
# ID 7268 (Row 7268, Index Label: 7327): Extracted: 'politics'
# ID 7269 (Row 7269, Index Label: 7328): Extracted: 'environment'
# ID 7270 (Row 7270, Index Label: 7329): Extracted: 'politics'
# ID 7271 (Row 7271, Index Label: 7330): Extracted: 'worldNews'
# ID 7272 (Row 7272, Index Label: 7331): Extracted: 'socialIssues'
# ID 7273 (Row 7273, Index Label: 7332): Extracted: 'government'
# ID 7274 (Row 7274, Index Label: 7333): Extracted: 'legal'
# ID 7275 (Row 7275, Index Label: 7334): Extracted: 'politics'
# ID 7276 (Row 7276, Index Label: 7335): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7277 (Row 7277, Index Label: 7336). Attempt 1/7. Waiting 19.1s (consecutive rate limits: 1)...
# ID 7277 (Row 7277, Index Label: 7336): Extracted: 'politics'
# ID 7278 (Row 7278, Index Label: 7337): Extracted: 'politics'
# ID 7279 (Row 7279, Index Label: 7338): Extracted: 'politics'
# ID 7280 (Row 7280, Index Label: 7339): Extracted: 'technology'
# ID 7281 (Row 7281, Index Label: 7340): Extracted: 'business'
# ID 7282 (Row 7282, Index Label: 7341): Extracted: 'politics'
# ID 7283 (Row 7283, Index Label: 7342): Extracted: 'politics'
# ID 7284 (Row 7284, Index Label: 7343): Extracted: 'politics'
# ID 7285 (Row 7285, Index Label: 7344): Extracted: 'politics'
# ID 7286 (Row 7286, Index Label: 7346): Extracted: 'politics'
# ID 7287 (Row 7287, Index Label: 7347): Extracted: 'politics'
# ID 7288 (Row 7288, Index Label: 7348): Extracted: 'politics'
# ID 7289 (Row 7289, Index Label: 7349): Extracted: 'politics'
# ID 7290 (Row 7290, Index Label: 7350): Extracted: 'politics'
# ID 7291 (Row 7291, Index Label: 7351): Extracted: 'crime'
# ID 7292 (Row 7292, Index Label: 7352): Extracted: 'health'
# ID 7293 (Row 7293, Index Label: 7353): Extracted: 'politics'
# ID 7294 (Row 7294, Index Label: 7354): Extracted: 'politics'
# ID 7295 (Row 7295, Index Label: 7355): Extracted: 'politics'
# ID 7296 (Row 7296, Index Label: 7356): Extracted: 'finance'
# ID 7297 (Row 7297, Index Label: 7357): Extracted: 'politics'
# ID 7298 (Row 7298, Index Label: 7358): Extracted: 'politics'
# ID 7299 (Row 7299, Index Label: 7359): Extracted: 'politics'
# ID 7300 (Row 7300, Index Label: 7360): Extracted: 'health'
# ID 7301 (Row 7301, Index Label: 7361): Extracted: 'health'
# ID 7302 (Row 7302, Index Label: 7362): Extracted: 'politics'
#
# Processing item 201/2898 in current range (ID: 7303)...
# WARN: Rate limit hit for Article ID 7303 (Row 7303, Index Label: 7363). Attempt 1/7. Waiting 20.2s (consecutive rate limits: 1)...
# ID 7303 (Row 7303, Index Label: 7363): Extracted: 'environment'
# ID 7304 (Row 7304, Index Label: 7364): Extracted: 'politics'
# ID 7305 (Row 7305, Index Label: 7365): Extracted: 'politics'
# ID 7306 (Row 7306, Index Label: 7366): Extracted: 'politics'
# ID 7307 (Row 7307, Index Label: 7367): Extracted: 'business'
# ID 7308 (Row 7308, Index Label: 7368): Extracted: 'politics'
# ID 7309 (Row 7309, Index Label: 7369): Extracted: 'politics'
# ID 7310 (Row 7310, Index Label: 7370): Extracted: 'politics'
# ID 7311 (Row 7311, Index Label: 7371): Extracted: 'government'
# ID 7312 (Row 7312, Index Label: 7372): Extracted: 'politics'
# ID 7313 (Row 7313, Index Label: 7373): Extracted: 'politics'
# ID 7314 (Row 7314, Index Label: 7374): Extracted: 'politics'
# ID 7315 (Row 7315, Index Label: 7375): Extracted: 'politics'
# ID 7316 (Row 7316, Index Label: 7376): Extracted: 'politics'
# ID 7317 (Row 7317, Index Label: 7377): Extracted: 'politics'
# ID 7318 (Row 7318, Index Label: 7378): Extracted: 'politics'
# ID 7319 (Row 7319, Index Label: 7379): Extracted: 'politics'
# ID 7320 (Row 7320, Index Label: 7380): Extracted: 'politics'
# ID 7321 (Row 7321, Index Label: 7381): Extracted: 'politics'
# ID 7322 (Row 7322, Index Label: 7382): Extracted: 'politics'
# ID 7323 (Row 7323, Index Label: 7383): Extracted: 'politics'
# ID 7324 (Row 7324, Index Label: 7384): Extracted: 'usNews'
# ID 7325 (Row 7325, Index Label: 7385): Extracted: 'socialIssues'
# ID 7326 (Row 7326, Index Label: 7386): Extracted: 'politics'
# ID 7327 (Row 7327, Index Label: 7387): Extracted: 'politics'
# ID 7328 (Row 7328, Index Label: 7388): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7329 (Row 7329, Index Label: 7389). Attempt 1/7. Waiting 19.0s (consecutive rate limits: 1)...
# ID 7329 (Row 7329, Index Label: 7389): Extracted: 'socialIssues'
# ID 7330 (Row 7330, Index Label: 7390): Extracted: 'legal'
# ID 7331 (Row 7331, Index Label: 7391): Extracted: 'politics'
# ID 7332 (Row 7332, Index Label: 7392): Extracted: 'worldNews'
# ID 7333 (Row 7333, Index Label: 7393): Extracted: 'politics'
# ID 7334 (Row 7334, Index Label: 7394): Extracted: 'politics'
# ID 7335 (Row 7335, Index Label: 7395): Extracted: 'politics'
# ID 7336 (Row 7336, Index Label: 7396): Extracted: 'politics'
# ID 7337 (Row 7337, Index Label: 7397): Extracted: 'politics'
# ID 7338 (Row 7338, Index Label: 7398): Extracted: 'politics'
# ID 7339 (Row 7339, Index Label: 7399): Extracted: 'politics'
# ID 7340 (Row 7340, Index Label: 7400): Extracted: 'politics'
# ID 7341 (Row 7341, Index Label: 7401): Extracted: 'politics'
# ID 7342 (Row 7342, Index Label: 7402): Extracted: 'environment'
# ID 7343 (Row 7343, Index Label: 7403): Extracted: 'worldNews'
# ID 7344 (Row 7344, Index Label: 7404): Extracted: 'politics'
# ID 7345 (Row 7345, Index Label: 7405): Extracted: 'usNews'
# ID 7346 (Row 7346, Index Label: 7406): Extracted: 'health'
# ID 7347 (Row 7347, Index Label: 7407): Extracted: 'politics'
# ID 7348 (Row 7348, Index Label: 7408): Extracted: 'politics'
# ID 7349 (Row 7349, Index Label: 7409): Extracted: 'worldNews'
# ID 7350 (Row 7350, Index Label: 7410): Extracted: 'politics'
# ID 7351 (Row 7351, Index Label: 7411): Extracted: 'politics'
# ID 7352 (Row 7352, Index Label: 7412): Extracted: 'politics'
# ID 7353 (Row 7353, Index Label: 7413): Extracted: 'politics'
# ID 7354 (Row 7354, Index Label: 7414): Extracted: 'politics'
# ID 7355 (Row 7355, Index Label: 7415): Extracted: 'socialIssues'
# ID 7356 (Row 7356, Index Label: 7416): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7357 (Row 7357, Index Label: 7417). Attempt 1/7. Waiting 20.0s (consecutive rate limits: 1)...
# ID 7357 (Row 7357, Index Label: 7417): Extracted: 'politics'
# ID 7358 (Row 7358, Index Label: 7418): Extracted: 'politics'
# ID 7359 (Row 7359, Index Label: 7419): Extracted: 'politics'
# ID 7360 (Row 7360, Index Label: 7420): Extracted: 'politics'
# ID 7361 (Row 7361, Index Label: 7421): Extracted: 'politics'
# ID 7362 (Row 7362, Index Label: 7422): Extracted: 'politics'
# ID 7363 (Row 7363, Index Label: 7423): Extracted: 'worldNews'
# ID 7364 (Row 7364, Index Label: 7424): Extracted: 'middleEastNews'
# ID 7365 (Row 7365, Index Label: 7425): Extracted: 'politics'
# ID 7366 (Row 7366, Index Label: 7426): Extracted: 'politics'
# ID 7367 (Row 7367, Index Label: 7427): Extracted: 'politics'
# ID 7368 (Row 7368, Index Label: 7428): Extracted: 'politics'
# ID 7369 (Row 7369, Index Label: 7429): Extracted: 'politics'
# ID 7370 (Row 7370, Index Label: 7430): Extracted: 'politics'
# ID 7371 (Row 7371, Index Label: 7431): Extracted: 'politics'
# ID 7372 (Row 7372, Index Label: 7432): Extracted: 'worldNews'
# ID 7373 (Row 7373, Index Label: 7433): Extracted: 'socialIssues'
# ID 7374 (Row 7374, Index Label: 7434): Extracted: 'politics'
# ID 7375 (Row 7375, Index Label: 7435): Extracted: 'politics'
# ID 7376 (Row 7376, Index Label: 7436): Extracted: 'middleEastNews'
# ID 7377 (Row 7377, Index Label: 7437): Extracted: 'politics'
# ID 7378 (Row 7378, Index Label: 7438): Extracted: 'politics'
# ID 7379 (Row 7379, Index Label: 7439): Extracted: 'worldNews'
# ID 7380 (Row 7380, Index Label: 7440): Extracted: 'worldNews'
# ID 7381 (Row 7381, Index Label: 7441): Extracted: 'worldNews'
# ID 7382 (Row 7382, Index Label: 7442): Extracted: 'politics'
# ID 7383 (Row 7383, Index Label: 7443): Extracted: 'politics'
# ID 7384 (Row 7384, Index Label: 7444): Extracted: 'politics'
# ID 7385 (Row 7385, Index Label: 7445): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7386 (Row 7386, Index Label: 7446). Attempt 1/7. Waiting 20.2s (consecutive rate limits: 1)...
# ID 7386 (Row 7386, Index Label: 7446): Extracted: 'politics'
# ID 7387 (Row 7387, Index Label: 7447): Extracted: 'politics'
# ID 7388 (Row 7388, Index Label: 7448): Extracted: 'politics'
# ID 7389 (Row 7389, Index Label: 7449): Extracted: 'middleEastNews'
# ID 7390 (Row 7390, Index Label: 7450): Extracted: 'politics'
# ID 7391 (Row 7391, Index Label: 7451): Extracted: 'usNews'
# ID 7392 (Row 7392, Index Label: 7452): Extracted: 'politics'
# ID 7393 (Row 7393, Index Label: 7453): Extracted: 'politics'
# ID 7394 (Row 7394, Index Label: 7454): Extracted: 'politics'
# ID 7395 (Row 7395, Index Label: 7455): Extracted: 'politics'
# ID 7396 (Row 7396, Index Label: 7456): Extracted: 'socialIssues'
# ID 7397 (Row 7397, Index Label: 7457): Extracted: 'politics'
# ID 7398 (Row 7398, Index Label: 7459): Extracted: 'politics'
# ID 7399 (Row 7399, Index Label: 7460): Extracted: 'worldNews'
# ID 7400 (Row 7400, Index Label: 7461): Extracted: 'politics'
# ID 7401 (Row 7401, Index Label: 7462): Extracted: 'middleEastNews'
# ID 7402 (Row 7402, Index Label: 7463): Extracted: 'politics'
#
# Processing item 301/2898 in current range (ID: 7403)...
# ID 7403 (Row 7403, Index Label: 7464): Extracted: 'politics'
# ID 7404 (Row 7404, Index Label: 7465): Extracted: 'politics'
# ID 7405 (Row 7405, Index Label: 7466): Extracted: 'politics'
# ID 7406 (Row 7406, Index Label: 7467): Extracted: 'middleEastNews'
# ID 7407 (Row 7407, Index Label: 7468): Extracted: 'politics'
# ID 7408 (Row 7408, Index Label: 7469): Extracted: 'politics'
# ID 7409 (Row 7409, Index Label: 7470): Extracted: 'politics'
# ID 7410 (Row 7410, Index Label: 7471): Extracted: 'politics'
# ID 7411 (Row 7411, Index Label: 7472): Extracted: 'politics'
# ID 7412 (Row 7412, Index Label: 7473): Extracted: 'politics'
# ID 7413 (Row 7413, Index Label: 7474): Extracted: 'politics'
# ID 7414 (Row 7414, Index Label: 7475): Extracted: 'politics'
# ID 7415 (Row 7415, Index Label: 7476): Extracted: 'finance'
# WARN: Rate limit hit for Article ID 7416 (Row 7416, Index Label: 7477). Attempt 1/7. Waiting 19.7s (consecutive rate limits: 1)...
# ID 7416 (Row 7416, Index Label: 7477): Extracted: 'politics'
# ID 7417 (Row 7417, Index Label: 7478): Extracted: 'politics'
# ID 7418 (Row 7418, Index Label: 7479): Extracted: 'politics'
# ID 7419 (Row 7419, Index Label: 7480): Extracted: 'politics'
# ID 7420 (Row 7420, Index Label: 7481): Extracted: 'politics'
# ID 7421 (Row 7421, Index Label: 7482): Extracted: 'worldNews'
# ID 7422 (Row 7422, Index Label: 7483): Extracted: 'worldNews'
# ID 7423 (Row 7423, Index Label: 7484): Extracted: 'politics'
# ID 7424 (Row 7424, Index Label: 7485): Extracted: 'politics'
# ID 7425 (Row 7425, Index Label: 7486): Extracted: 'politics'
# ID 7426 (Row 7426, Index Label: 7487): Extracted: 'politics'
# ID 7427 (Row 7427, Index Label: 7488): Extracted: 'health'
# ID 7428 (Row 7428, Index Label: 7489): Extracted: 'politics'
# ID 7429 (Row 7429, Index Label: 7490): Extracted: 'politics'
# ID 7430 (Row 7430, Index Label: 7491): Extracted: 'usNews'
# ID 7431 (Row 7431, Index Label: 7492): Extracted: 'politics'
# ID 7432 (Row 7432, Index Label: 7493): Extracted: 'politics'
# ID 7433 (Row 7433, Index Label: 7494): Extracted: 'politics'
# ID 7434 (Row 7434, Index Label: 7495): Extracted: 'politics'
# ID 7435 (Row 7435, Index Label: 7496): Extracted: 'business'
# ID 7436 (Row 7436, Index Label: 7497): Extracted: 'usNews'
# ID 7437 (Row 7437, Index Label: 7498): Extracted: 'usNews'
# ID 7438 (Row 7438, Index Label: 7499): Extracted: 'politics'
# ID 7439 (Row 7439, Index Label: 7500): Extracted: 'politics'
# ID 7440 (Row 7440, Index Label: 7501): Extracted: 'politics'
# ID 7441 (Row 7441, Index Label: 7502): Extracted: 'crime'
# ID 7442 (Row 7442, Index Label: 7503): Extracted: 'socialIssues'
# ID 7443 (Row 7443, Index Label: 7504): Extracted: 'politics'
# ID 7444 (Row 7444, Index Label: 7505): Extracted: 'politics'
# ID 7445 (Row 7445, Index Label: 7506): Extracted: 'environment'
# WARN: Rate limit hit for Article ID 7446 (Row 7446, Index Label: 7507). Attempt 1/7. Waiting 20.1s (consecutive rate limits: 1)...
# ID 7446 (Row 7446, Index Label: 7507): Extracted: 'worldNews'
# ID 7447 (Row 7447, Index Label: 7508): Extracted: 'worldNews'
# ID 7448 (Row 7448, Index Label: 7509): Extracted: 'politics'
# ID 7449 (Row 7449, Index Label: 7510): Extracted: 'worldNews'
# ID 7450 (Row 7450, Index Label: 7511): Extracted: 'socialIssues'
# ID 7451 (Row 7451, Index Label: 7512): Extracted: 'worldNews'
# ID 7452 (Row 7452, Index Label: 7513): Extracted: 'politics'
# ID 7453 (Row 7453, Index Label: 7514): Extracted: 'politics'
# ID 7454 (Row 7454, Index Label: 7515): Extracted: 'politics'
# ID 7455 (Row 7455, Index Label: 7516): Extracted: 'business'
# ID 7456 (Row 7456, Index Label: 7517): Extracted: 'politics'
# ID 7457 (Row 7457, Index Label: 7518): Extracted: 'legal'
# ID 7458 (Row 7458, Index Label: 7519): Extracted: 'politics'
# ID 7459 (Row 7459, Index Label: 7520): Extracted: 'government'
# ID 7460 (Row 7460, Index Label: 7521): Extracted: 'technology'
# ID 7461 (Row 7461, Index Label: 7522): Extracted: 'politics'
# ID 7462 (Row 7462, Index Label: 7523): Extracted: 'entertainment'
# ID 7463 (Row 7463, Index Label: 7524): Extracted: 'politics'
# ID 7464 (Row 7464, Index Label: 7525): Extracted: 'politics'
# ID 7465 (Row 7465, Index Label: 7526): Extracted: 'politics'
# ID 7466 (Row 7466, Index Label: 7527): Extracted: 'politics'
# ID 7467 (Row 7467, Index Label: 7528): Extracted: 'politics'
# ID 7468 (Row 7468, Index Label: 7529): Extracted: 'politics'
# ID 7469 (Row 7469, Index Label: 7530): Extracted: 'politics'
# ID 7470 (Row 7470, Index Label: 7531): Extracted: 'politics'
# ID 7471 (Row 7471, Index Label: 7532): Extracted: 'politics'
# ID 7472 (Row 7472, Index Label: 7533): Extracted: 'politics'
# ID 7473 (Row 7473, Index Label: 7534): Extracted: 'politics'
# ID 7474 (Row 7474, Index Label: 7535): Extracted: 'politics'
# ID 7475 (Row 7475, Index Label: 7536): Extracted: 'worldNews'
# WARN: Rate limit hit for Article ID 7476 (Row 7476, Index Label: 7537). Attempt 1/7. Waiting 19.7s (consecutive rate limits: 1)...
# ID 7476 (Row 7476, Index Label: 7537): Extracted: 'politics'
# ID 7477 (Row 7477, Index Label: 7538): Extracted: 'legal'
# ID 7478 (Row 7478, Index Label: 7539): Extracted: 'politics'
# ID 7479 (Row 7479, Index Label: 7540): Extracted: 'politics'
# ID 7480 (Row 7480, Index Label: 7541): Extracted: 'politics'
# ID 7481 (Row 7481, Index Label: 7542): Extracted: 'politics'
# ID 7482 (Row 7482, Index Label: 7543): Extracted: 'politics'
# ID 7483 (Row 7483, Index Label: 7544): Extracted: 'politics'
# ID 7484 (Row 7484, Index Label: 7545): Extracted: 'entertainment'
# ID 7485 (Row 7485, Index Label: 7546): Extracted: 'politics'
# ID 7486 (Row 7486, Index Label: 7547): Extracted: 'politics'
# ID 7487 (Row 7487, Index Label: 7548): Extracted: 'politics'
# ID 7488 (Row 7488, Index Label: 7549): Extracted: 'politics'
# ID 7489 (Row 7489, Index Label: 7550): Extracted: 'politics'
# ID 7490 (Row 7490, Index Label: 7551): Extracted: 'politics'
# ID 7491 (Row 7491, Index Label: 7552): Extracted: 'politics'
# ID 7492 (Row 7492, Index Label: 7553): Extracted: 'politics'
# ID 7493 (Row 7493, Index Label: 7554): Extracted: 'business'
# ID 7494 (Row 7494, Index Label: 7555): Extracted: 'politics'
# ID 7495 (Row 7495, Index Label: 7556): Extracted: 'politics'
# ID 7496 (Row 7496, Index Label: 7557): Extracted: 'socialIssues'
# ID 7497 (Row 7497, Index Label: 7558): Extracted: 'legal'
# ID 7498 (Row 7498, Index Label: 7559): Extracted: 'politics'
# ID 7499 (Row 7499, Index Label: 7560): Extracted: 'politics'
# ID 7500 (Row 7500, Index Label: 7561): Extracted: 'politics'
# ID 7501 (Row 7501, Index Label: 7562): Extracted: 'politics'
# ID 7502 (Row 7502, Index Label: 7563): Extracted: 'politics'
#
# Processing item 401/2898 in current range (ID: 7503)...
# ID 7503 (Row 7503, Index Label: 7564): Extracted: 'politics'
# ID 7504 (Row 7504, Index Label: 7565): Extracted: 'politics'
# ID 7505 (Row 7505, Index Label: 7566): Extracted: 'usNews'
# ID 7506 (Row 7506, Index Label: 7567): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7507 (Row 7507, Index Label: 7568). Attempt 1/7. Waiting 19.5s (consecutive rate limits: 1)...
# ID 7507 (Row 7507, Index Label: 7568): Extracted: 'politics'
# ID 7508 (Row 7508, Index Label: 7569): Extracted: 'finance'
# ID 7509 (Row 7509, Index Label: 7570): Extracted: 'politics'
# ID 7510 (Row 7510, Index Label: 7571): Extracted: 'worldNews'
# ID 7511 (Row 7511, Index Label: 7572): Extracted: 'usNews'
# ID 7512 (Row 7512, Index Label: 7573): Extracted: 'usNews'
# ID 7513 (Row 7513, Index Label: 7574): Extracted: 'politics'
# ID 7514 (Row 7514, Index Label: 7575): Extracted: 'socialIssues'
# ID 7515 (Row 7515, Index Label: 7576): Extracted: 'politics'
# ID 7516 (Row 7516, Index Label: 7577): Extracted: 'health'
# ID 7517 (Row 7517, Index Label: 7578): Extracted: 'politics'
# ID 7518 (Row 7518, Index Label: 7579): Extracted: 'politics'
# ID 7519 (Row 7519, Index Label: 7580): Extracted: 'politics'
# ID 7520 (Row 7520, Index Label: 7581): Extracted: 'sports'
# ID 7521 (Row 7521, Index Label: 7582): Extracted: 'politics'
# ID 7522 (Row 7522, Index Label: 7583): Extracted: 'politics'
# ID 7523 (Row 7523, Index Label: 7584): Extracted: 'politics'
# ID 7524 (Row 7524, Index Label: 7585): Extracted: 'politics'
# ID 7525 (Row 7525, Index Label: 7586): Extracted: 'politics'
# ID 7526 (Row 7526, Index Label: 7587): Extracted: 'politics'
# ID 7527 (Row 7527, Index Label: 7588): Extracted: 'politics'
# ID 7528 (Row 7528, Index Label: 7589): Extracted: 'politics'
# ID 7529 (Row 7529, Index Label: 7590): Extracted: 'politics'
# ID 7530 (Row 7530, Index Label: 7591): Extracted: 'politics'
# ID 7531 (Row 7531, Index Label: 7592): Extracted: 'politics'
# ID 7532 (Row 7532, Index Label: 7593): Extracted: 'politics'
# ID 7533 (Row 7533, Index Label: 7594): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7534 (Row 7534, Index Label: 7595). Attempt 1/7. Waiting 19.5s (consecutive rate limits: 1)...
# ID 7534 (Row 7534, Index Label: 7595): Extracted: 'politics'
# ID 7535 (Row 7535, Index Label: 7596): Extracted: 'politics'
# ID 7536 (Row 7536, Index Label: 7597): Extracted: 'politics'
# ID 7537 (Row 7537, Index Label: 7598): Extracted: 'socialIssues'
# ID 7538 (Row 7538, Index Label: 7599): Extracted: 'politics'
# ID 7539 (Row 7539, Index Label: 7600): Extracted: 'crime'
# ID 7540 (Row 7540, Index Label: 7601): Extracted: 'politics'
# ID 7541 (Row 7541, Index Label: 7602): Extracted: 'politics'
# ID 7542 (Row 7542, Index Label: 7603): Extracted: 'politics'
# ID 7543 (Row 7543, Index Label: 7604): Extracted: 'politics'
# ID 7544 (Row 7544, Index Label: 7605): Extracted: 'socialIssues'
# ID 7545 (Row 7545, Index Label: 7606): Extracted: 'politics'
# ID 7546 (Row 7546, Index Label: 7607): Extracted: 'politics'
# ID 7547 (Row 7547, Index Label: 7608): Extracted: 'socialIssues'
# ID 7548 (Row 7548, Index Label: 7609): Extracted: 'politics'
# ID 7549 (Row 7549, Index Label: 7610): Extracted: 'business'
# ID 7550 (Row 7550, Index Label: 7611): Extracted: 'politics'
# ID 7551 (Row 7551, Index Label: 7612): Extracted: 'usNews'
# ID 7552 (Row 7552, Index Label: 7613): Extracted: 'politics'
# ID 7553 (Row 7553, Index Label: 7614): Extracted: 'business'
# ID 7554 (Row 7554, Index Label: 7615): Extracted: 'worldNews'
# ID 7555 (Row 7555, Index Label: 7616): Extracted: 'voting rights'
# ID 7556 (Row 7556, Index Label: 7617): Extracted: 'politics'
# ID 7557 (Row 7557, Index Label: 7618): Extracted: 'environment'
# ID 7558 (Row 7558, Index Label: 7619): Extracted: 'politics'
# ID 7559 (Row 7559, Index Label: 7620): Extracted: 'politics'
# ID 7560 (Row 7560, Index Label: 7621): Extracted: 'legal'
# WARN: Rate limit hit for Article ID 7561 (Row 7561, Index Label: 7622). Attempt 1/7. Waiting 19.2s (consecutive rate limits: 1)...
# ID 7561 (Row 7561, Index Label: 7622): Extracted: 'politics'
# ID 7562 (Row 7562, Index Label: 7623): Extracted: 'technology'
# ID 7563 (Row 7563, Index Label: 7624): Extracted: 'politics'
# ID 7564 (Row 7564, Index Label: 7625): Extracted: 'politics'
# ID 7565 (Row 7565, Index Label: 7626): Extracted: 'politics'
# ID 7566 (Row 7566, Index Label: 7627): Extracted: 'politics'
# ID 7567 (Row 7567, Index Label: 7628): Extracted: 'politics'
# ID 7568 (Row 7568, Index Label: 7629): Extracted: 'finance'
# ID 7569 (Row 7569, Index Label: 7630): Extracted: 'environment'
# ID 7570 (Row 7570, Index Label: 7631): Extracted: 'politics'
# ID 7571 (Row 7571, Index Label: 7632): Extracted: 'politics'
# ID 7572 (Row 7572, Index Label: 7633): Extracted: 'politics'
# ID 7573 (Row 7573, Index Label: 7634): Extracted: 'entertainment'
# ID 7574 (Row 7574, Index Label: 7635): Extracted: 'politics'
# ID 7575 (Row 7575, Index Label: 7636): Extracted: 'politics'
# ID 7576 (Row 7576, Index Label: 7637): Extracted: 'politics'
# ID 7577 (Row 7577, Index Label: 7638): Extracted: 'politics'
# ID 7578 (Row 7578, Index Label: 7639): Extracted: 'politics'
# ID 7579 (Row 7579, Index Label: 7640): Extracted: 'politics'
# ID 7580 (Row 7580, Index Label: 7641): Extracted: 'politics'
# ID 7581 (Row 7581, Index Label: 7642): Extracted: 'politics'
# ID 7582 (Row 7582, Index Label: 7643): Extracted: 'politics'
# ID 7583 (Row 7583, Index Label: 7644): Extracted: 'politics'
# ID 7584 (Row 7584, Index Label: 7645): Extracted: 'politics'
# ID 7585 (Row 7585, Index Label: 7646): Extracted: 'politics'
# ID 7586 (Row 7586, Index Label: 7647): Extracted: 'politics'
# ID 7587 (Row 7587, Index Label: 7648): Extracted: 'politics'
# ID 7588 (Row 7588, Index Label: 7649): Extracted: 'politics'
# ID 7589 (Row 7589, Index Label: 7650): Extracted: 'politics'
# ID 7590 (Row 7590, Index Label: 7651): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7591 (Row 7591, Index Label: 7652). Attempt 1/7. Waiting 20.5s (consecutive rate limits: 1)...
# ID 7591 (Row 7591, Index Label: 7652): Extracted: 'socialIssues'
# ID 7592 (Row 7592, Index Label: 7653): Extracted: 'politics'
# ID 7593 (Row 7593, Index Label: 7654): Extracted: 'politics'
# ID 7594 (Row 7594, Index Label: 7656): Extracted: 'politics'
# ID 7595 (Row 7595, Index Label: 7657): Extracted: 'politics'
# ID 7596 (Row 7596, Index Label: 7658): Extracted: 'politics'
# ID 7597 (Row 7597, Index Label: 7659): Extracted: 'politics'
# ID 7598 (Row 7598, Index Label: 7660): Extracted: 'politics'
# ID 7599 (Row 7599, Index Label: 7661): Extracted: 'politics'
# ID 7600 (Row 7600, Index Label: 7662): Extracted: 'politics'
# ID 7601 (Row 7601, Index Label: 7663): Extracted: 'politics'
# ID 7602 (Row 7602, Index Label: 7664): Extracted: 'politics'
#
# Processing item 501/2898 in current range (ID: 7603)...
# ID 7603 (Row 7603, Index Label: 7665): Extracted: 'politics'
# ID 7604 (Row 7604, Index Label: 7666): Extracted: 'politics'
# ID 7605 (Row 7605, Index Label: 7667): Extracted: 'politics'
# ID 7606 (Row 7606, Index Label: 7668): Extracted: 'health'
# ID 7607 (Row 7607, Index Label: 7669): Extracted: 'politics'
# ID 7608 (Row 7608, Index Label: 7670): Extracted: 'politics'
# ID 7609 (Row 7609, Index Label: 7671): Extracted: 'politics'
# ID 7610 (Row 7610, Index Label: 7672): Extracted: 'politics'
# ID 7611 (Row 7611, Index Label: 7673): Extracted: 'politics'
# ID 7612 (Row 7612, Index Label: 7674): Extracted: 'politics'
# ID 7613 (Row 7613, Index Label: 7675): Extracted: 'socialIssues'
# ID 7614 (Row 7614, Index Label: 7676): Extracted: 'politics'
# ID 7615 (Row 7615, Index Label: 7677): Extracted: 'worldNews'
# ID 7616 (Row 7616, Index Label: 7678): Extracted: 'politics'
# ID 7617 (Row 7617, Index Label: 7679): Extracted: 'health'
# ID 7618 (Row 7618, Index Label: 7680): Extracted: 'politics'
# ID 7619 (Row 7619, Index Label: 7681): Extracted: 'politics'
# ID 7620 (Row 7620, Index Label: 7682): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7621 (Row 7621, Index Label: 7683). Attempt 1/7. Waiting 20.5s (consecutive rate limits: 1)...
# ID 7621 (Row 7621, Index Label: 7683): Extracted: 'politics'
# ID 7622 (Row 7622, Index Label: 7684): Extracted: 'politics'
# ID 7623 (Row 7623, Index Label: 7685): Extracted: 'politics'
# ID 7624 (Row 7624, Index Label: 7686): Extracted: 'technology'
# ID 7625 (Row 7625, Index Label: 7687): Extracted: 'politics'
# ID 7626 (Row 7626, Index Label: 7688): Extracted: 'politics'
# ID 7627 (Row 7627, Index Label: 7689): Extracted: 'worldNews'
# ID 7628 (Row 7628, Index Label: 7690): Extracted: 'politics'
# ID 7629 (Row 7629, Index Label: 7691): Extracted: 'finance'
# ID 7630 (Row 7630, Index Label: 7692): Extracted: 'entertainment'
# ID 7631 (Row 7631, Index Label: 7693): Extracted: 'politics'
# ID 7632 (Row 7632, Index Label: 7694): Extracted: 'politics'
# ID 7633 (Row 7633, Index Label: 7695): Extracted: 'politics'
# ID 7634 (Row 7634, Index Label: 7696): Extracted: 'politics'
# ID 7635 (Row 7635, Index Label: 7697): Extracted: 'politics'
# ID 7636 (Row 7636, Index Label: 7698): Extracted: 'politics'
# ID 7637 (Row 7637, Index Label: 7699): Extracted: 'worldNews'
# ID 7638 (Row 7638, Index Label: 7700): Extracted: 'politics'
# ID 7639 (Row 7639, Index Label: 7701): Extracted: 'politics'
# ID 7640 (Row 7640, Index Label: 7702): Extracted: 'politics'
# ID 7641 (Row 7641, Index Label: 7703): Extracted: 'politics'
# ID 7642 (Row 7642, Index Label: 7704): Extracted: 'politics'
# ID 7643 (Row 7643, Index Label: 7705): Extracted: 'environment'
# ID 7644 (Row 7644, Index Label: 7706): Extracted: 'politics'
# ID 7645 (Row 7645, Index Label: 7707): Extracted: 'politics'
# ID 7646 (Row 7646, Index Label: 7708): Extracted: 'technology'
# ID 7647 (Row 7647, Index Label: 7709): Extracted: 'politics'
# ID 7648 (Row 7648, Index Label: 7710): Extracted: 'middleEastNews'
# ID 7649 (Row 7649, Index Label: 7711): Extracted: 'environment'
# ID 7650 (Row 7650, Index Label: 7712): Extracted: 'politics'
# ID 7651 (Row 7651, Index Label: 7713): Extracted: 'business'
# ID 7652 (Row 7652, Index Label: 7714): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7653 (Row 7653, Index Label: 7715). Attempt 1/7. Waiting 21.0s (consecutive rate limits: 1)...
# ID 7653 (Row 7653, Index Label: 7715): Extracted: 'politics'
# ID 7654 (Row 7654, Index Label: 7716): Extracted: 'health'
# ID 7655 (Row 7655, Index Label: 7717): Extracted: 'legal'
# ID 7656 (Row 7656, Index Label: 7718): Extracted: 'socialIssues'
# ID 7657 (Row 7657, Index Label: 7719): Extracted: 'politics'
# ID 7658 (Row 7658, Index Label: 7720): Extracted: 'politics'
# ID 7659 (Row 7659, Index Label: 7721): Extracted: 'politics'
# ID 7660 (Row 7660, Index Label: 7722): Extracted: 'politics'
# ID 7661 (Row 7661, Index Label: 7723): Extracted: 'politics'
# ID 7662 (Row 7662, Index Label: 7724): Extracted: 'finance'
# ID 7663 (Row 7663, Index Label: 7725): Extracted: 'business'
# ID 7664 (Row 7664, Index Label: 7726): Extracted: 'politics'
# ID 7665 (Row 7665, Index Label: 7727): Extracted: 'politics'
# ID 7666 (Row 7666, Index Label: 7728): Extracted: 'politics'
# ID 7667 (Row 7667, Index Label: 7729): Extracted: 'politics'
# ID 7668 (Row 7668, Index Label: 7730): Extracted: 'politics'
# ID 7669 (Row 7669, Index Label: 7731): Extracted: 'business'
# ID 7670 (Row 7670, Index Label: 7732): Extracted: 'politics'
# ID 7671 (Row 7671, Index Label: 7733): Extracted: 'politics'
# ID 7672 (Row 7672, Index Label: 7734): Extracted: 'politics'
# ID 7673 (Row 7673, Index Label: 7735): Extracted: 'politics'
# ID 7674 (Row 7674, Index Label: 7736): Extracted: 'worldNews'
# ID 7675 (Row 7675, Index Label: 7737): Extracted: 'politics'
# ID 7676 (Row 7676, Index Label: 7738): Extracted: 'politics'
# ID 7677 (Row 7677, Index Label: 7739): Extracted: 'politics'
# ID 7678 (Row 7678, Index Label: 7740): Extracted: 'politics'
# ID 7679 (Row 7679, Index Label: 7741): Extracted: 'politics'
# ID 7680 (Row 7680, Index Label: 7742): Extracted: 'politics'
# ID 7681 (Row 7681, Index Label: 7743): Extracted: 'politics'
# ID 7682 (Row 7682, Index Label: 7744): Extracted: 'worldNews'
# ID 7683 (Row 7683, Index Label: 7745): Extracted: 'politics'
# ID 7684 (Row 7684, Index Label: 7746): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7685 (Row 7685, Index Label: 7747). Attempt 1/7. Waiting 19.4s (consecutive rate limits: 1)...
# ID 7685 (Row 7685, Index Label: 7747): Extracted: 'politics'
# ID 7686 (Row 7686, Index Label: 7748): Extracted: 'politics'
# ID 7687 (Row 7687, Index Label: 7749): Extracted: 'usNews'
# ID 7688 (Row 7688, Index Label: 7750): Extracted: 'usNews'
# ID 7689 (Row 7689, Index Label: 7751): Extracted: 'health'
# ID 7690 (Row 7690, Index Label: 7752): Extracted: 'politics'
# ID 7691 (Row 7691, Index Label: 7753): Extracted: 'socialIssues'
# ID 7692 (Row 7692, Index Label: 7754): Extracted: 'politics'
# ID 7693 (Row 7693, Index Label: 7755): Extracted: 'politics'
# ID 7694 (Row 7694, Index Label: 7756): Extracted: 'politics'
# ID 7695 (Row 7695, Index Label: 7757): Extracted: 'worldNews'
# ID 7696 (Row 7696, Index Label: 7758): Extracted: 'politics'
# ID 7697 (Row 7697, Index Label: 7759): Extracted: 'socialIssues'
# ID 7698 (Row 7698, Index Label: 7760): Extracted: 'politics'
# ID 7699 (Row 7699, Index Label: 7761): Extracted: 'politics'
# ID 7700 (Row 7700, Index Label: 7762): Extracted: 'politics'
# ID 7701 (Row 7701, Index Label: 7763): Extracted: 'politics'
# ID 7702 (Row 7702, Index Label: 7764): Extracted: 'politics'
#
# Processing item 601/2898 in current range (ID: 7703)...
# ID 7703 (Row 7703, Index Label: 7765): Extracted: 'politics'
# ID 7704 (Row 7704, Index Label: 7766): Extracted: 'politics'
# ID 7705 (Row 7705, Index Label: 7767): Extracted: 'politics'
# ID 7706 (Row 7706, Index Label: 7768): Extracted: 'politics'
# ID 7707 (Row 7707, Index Label: 7769): Extracted: 'politics'
# ID 7708 (Row 7708, Index Label: 7770): Extracted: 'entertainment'
# WARN: Rate limit hit for Article ID 7709 (Row 7709, Index Label: 7771). Attempt 1/7. Waiting 19.6s (consecutive rate limits: 1)...
# ID 7709 (Row 7709, Index Label: 7771): Extracted: 'crime'
# ID 7710 (Row 7710, Index Label: 7772): Extracted: 'politics'
# ID 7711 (Row 7711, Index Label: 7773): Extracted: 'politics'
# ID 7712 (Row 7712, Index Label: 7774): Extracted: 'politics'
# ID 7713 (Row 7713, Index Label: 7775): Extracted: 'politics'
# ID 7714 (Row 7714, Index Label: 7776): Extracted: 'politics'
# ID 7715 (Row 7715, Index Label: 7777): Extracted: 'politics'
# ID 7716 (Row 7716, Index Label: 7778): Extracted: 'politics'
# ID 7717 (Row 7717, Index Label: 7779): Extracted: 'politics'
# ID 7718 (Row 7718, Index Label: 7780): Extracted: 'politics'
# ID 7719 (Row 7719, Index Label: 7781): Extracted: 'politics'
# ID 7720 (Row 7720, Index Label: 7782): Extracted: 'politics'
# ID 7721 (Row 7721, Index Label: 7783): Extracted: 'health'
# ID 7722 (Row 7722, Index Label: 7784): Extracted: 'worldNews'
# ID 7723 (Row 7723, Index Label: 7785): Extracted: 'politics'
# ID 7724 (Row 7724, Index Label: 7786): Extracted: 'politics'
# ID 7725 (Row 7725, Index Label: 7787): Extracted: 'politics'
# ID 7726 (Row 7726, Index Label: 7788): Extracted: 'politics'
# ID 7727 (Row 7727, Index Label: 7789): Extracted: 'politics'
# ID 7728 (Row 7728, Index Label: 7790): Extracted: 'usNews'
# ID 7729 (Row 7729, Index Label: 7791): Extracted: 'politics'
# ID 7730 (Row 7730, Index Label: 7792): Extracted: 'politics'
# ID 7731 (Row 7731, Index Label: 7793): Extracted: 'politics'
# ID 7732 (Row 7732, Index Label: 7794): Extracted: 'technology'
# WARN: Rate limit hit for Article ID 7733 (Row 7733, Index Label: 7795). Attempt 1/7. Waiting 19.8s (consecutive rate limits: 1)...
# ID 7733 (Row 7733, Index Label: 7795): Extracted: 'politics'
# ID 7734 (Row 7734, Index Label: 7796): Extracted: 'politics'
# ID 7735 (Row 7735, Index Label: 7797): Extracted: 'politics'
# ID 7736 (Row 7736, Index Label: 7798): Extracted: 'technology'
# ID 7737 (Row 7737, Index Label: 7800): Extracted: 'politics'
# ID 7738 (Row 7738, Index Label: 7801): Extracted: 'politics'
# ID 7739 (Row 7739, Index Label: 7802): Extracted: 'politics'
# ID 7740 (Row 7740, Index Label: 7803): Extracted: 'politics'
# ID 7741 (Row 7741, Index Label: 7804): Extracted: 'politics'
# ID 7742 (Row 7742, Index Label: 7805): Extracted: 'politics'
# ID 7743 (Row 7743, Index Label: 7806): Extracted: 'politics'
# ID 7744 (Row 7744, Index Label: 7807): Extracted: 'politics'
# ID 7745 (Row 7745, Index Label: 7808): Extracted: 'politics'
# ID 7746 (Row 7746, Index Label: 7809): Extracted: 'worldNews'
# ID 7747 (Row 7747, Index Label: 7810): Extracted: 'politics'
# ID 7748 (Row 7748, Index Label: 7811): Extracted: 'politics'
# ID 7749 (Row 7749, Index Label: 7812): Extracted: 'politics'
# ID 7750 (Row 7750, Index Label: 7813): Extracted: 'politics'
# ID 7751 (Row 7751, Index Label: 7814): Extracted: 'legal'
# ID 7752 (Row 7752, Index Label: 7815): Extracted: 'politics'
# ID 7753 (Row 7753, Index Label: 7816): Extracted: 'politics'
# ID 7754 (Row 7754, Index Label: 7817): Extracted: 'politics'
# ID 7755 (Row 7755, Index Label: 7818): Extracted: 'politics'
# ID 7756 (Row 7756, Index Label: 7819): Extracted: 'politics'
# ID 7757 (Row 7757, Index Label: 7820): Extracted: 'politics'
# ID 7758 (Row 7758, Index Label: 7821): Extracted: 'politics'
# ID 7759 (Row 7759, Index Label: 7822): Extracted: 'sports'
# ID 7760 (Row 7760, Index Label: 7823): Extracted: 'worldNews'
# ID 7761 (Row 7761, Index Label: 7824): Extracted: 'crime'
# ID 7762 (Row 7762, Index Label: 7825): Extracted: 'worldNews'
# WARN: Rate limit hit for Article ID 7763 (Row 7763, Index Label: 7826). Attempt 1/7. Waiting 20.8s (consecutive rate limits: 1)...
# ID 7763 (Row 7763, Index Label: 7826): Extracted: 'legal'
# ID 7764 (Row 7764, Index Label: 7827): Extracted: 'politics'
# ID 7765 (Row 7765, Index Label: 7828): Extracted: 'politics'
# ID 7766 (Row 7766, Index Label: 7829): Extracted: 'politics'
# ID 7767 (Row 7767, Index Label: 7830): Extracted: 'politics'
# ID 7768 (Row 7768, Index Label: 7831): Extracted: 'politics'
# ID 7769 (Row 7769, Index Label: 7832): Extracted: 'politics'
# ID 7770 (Row 7770, Index Label: 7833): Extracted: 'environment'
# ID 7771 (Row 7771, Index Label: 7834): Extracted: 'politics'
# ID 7772 (Row 7772, Index Label: 7835): Extracted: 'politics'
# ID 7773 (Row 7773, Index Label: 7836): Extracted: 'politics'
# ID 7774 (Row 7774, Index Label: 7837): Extracted: 'politics'
# ID 7775 (Row 7775, Index Label: 7838): Extracted: 'politics'
# ID 7776 (Row 7776, Index Label: 7839): Extracted: 'politics'
# ID 7777 (Row 7777, Index Label: 7840): Extracted: 'politics'
# ID 7778 (Row 7778, Index Label: 7841): Extracted: 'politics'
# ID 7779 (Row 7779, Index Label: 7842): Extracted: 'politics'
# ID 7780 (Row 7780, Index Label: 7843): Extracted: 'politics'
# ID 7781 (Row 7781, Index Label: 7844): Extracted: 'politics'
# ID 7782 (Row 7782, Index Label: 7845): Extracted: 'politics'
# ID 7783 (Row 7783, Index Label: 7846): Extracted: 'politics'
# ID 7784 (Row 7784, Index Label: 7847): Extracted: 'politics'
# ID 7785 (Row 7785, Index Label: 7848): Extracted: 'politics'
# ID 7786 (Row 7786, Index Label: 7849): Extracted: 'worldNews'
# ID 7787 (Row 7787, Index Label: 7850): Extracted: 'politics'
# ID 7788 (Row 7788, Index Label: 7851): Extracted: 'politics'
# ID 7789 (Row 7789, Index Label: 7852): Extracted: 'politics'
# ID 7790 (Row 7790, Index Label: 7853): Extracted: 'politics'
# ID 7791 (Row 7791, Index Label: 7854): Extracted: 'politics'
# ID 7792 (Row 7792, Index Label: 7855): Extracted: 'politics'
# ID 7793 (Row 7793, Index Label: 7856): Extracted: 'politics'
# ID 7794 (Row 7794, Index Label: 7857): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 7795 (Row 7795, Index Label: 7858). Attempt 1/7. Waiting 20.8s (consecutive rate limits: 1)...
# ID 7795 (Row 7795, Index Label: 7858): Extracted: 'politics'
# ID 7796 (Row 7796, Index Label: 7859): Extracted: 'politics'
# ID 7797 (Row 7797, Index Label: 7860): Extracted: 'finance'
# ID 7798 (Row 7798, Index Label: 7861): Extracted: 'legal'
# ID 7799 (Row 7799, Index Label: 7862): Extracted: 'politics'
# ID 7800 (Row 7800, Index Label: 7863): Extracted: 'technology'
# ID 7801 (Row 7801, Index Label: 7864): Extracted: 'business'
# ID 7802 (Row 7802, Index Label: 7865): Extracted: 'politics'
#
# Processing item 701/2898 in current range (ID: 7803)...
# ID 7803 (Row 7803, Index Label: 7866): Extracted: 'politics'
# ID 7804 (Row 7804, Index Label: 7867): Extracted: 'politics'
# ID 7805 (Row 7805, Index Label: 7868): Extracted: 'usNews'
# ID 7806 (Row 7806, Index Label: 7869): Extracted: 'politics'
# ID 7807 (Row 7807, Index Label: 7870): Extracted: 'socialIssues'
# ID 7808 (Row 7808, Index Label: 7871): Extracted: 'politics'
# ID 7809 (Row 7809, Index Label: 7872): Extracted: 'politics'
# ID 7810 (Row 7810, Index Label: 7873): Extracted: 'politics'
# ID 7811 (Row 7811, Index Label: 7874): Extracted: 'politics'
# ID 7812 (Row 7812, Index Label: 7875): Extracted: 'politics'
# ID 7813 (Row 7813, Index Label: 7876): Extracted: 'politics'
# ID 7814 (Row 7814, Index Label: 7877): Extracted: 'politics'
# ID 7815 (Row 7815, Index Label: 7878): Extracted: 'politics'
# ID 7816 (Row 7816, Index Label: 7879): Extracted: 'politics'
# ID 7817 (Row 7817, Index Label: 7880): Extracted: 'entertainment'
# ID 7818 (Row 7818, Index Label: 7881): Extracted: 'usNews'
# ...
# ID 9766 (Row 9766, Index Label: 9848): Extracted: 'politics'
# ID 9767 (Row 9767, Index Label: 9849): Extracted: 'politics'
# ID 9768 (Row 9768, Index Label: 9850): Extracted: 'middleEastNews'
# ID 9769 (Row 9769, Index Label: 9851): Extracted: 'politics'
# ID 9770 (Row 9770, Index Label: 9852): Extracted: 'socialIssues'
# ID 9771 (Row 9771, Index Label: 9853): Extracted: 'middleEastNews'
# ID 9772 (Row 9772, Index Label: 9854): Extracted: 'politics'
# ID 9773 (Row 9773, Index Label: 9855): Extracted: 'politics'
# ID 9774 (Row 9774, Index Label: 9856): Extracted: 'politics'
# ID 9775 (Row 9775, Index Label: 9857): Extracted: 'technology'
# ID 9776 (Row 9776, Index Label: 9858): Extracted: 'politics'
# ID 9777 (Row 9777, Index Label: 9859): Extracted: 'worldNews'
# ID 9778 (Row 9778, Index Label: 9860): Extracted: 'politics'
# ID 9779 (Row 9779, Index Label: 9861): Extracted: 'technology'
# ID 9780 (Row 9780, Index Label: 9862): Extracted: 'politics'
# ID 9781 (Row 9781, Index Label: 9863): Extracted: 'politics'
# ID 9782 (Row 9782, Index Label: 9864): Extracted: 'legal'
# ID 9783 (Row 9783, Index Label: 9865): Extracted: 'government'
# ID 9784 (Row 9784, Index Label: 9866): Extracted: 'health'
# ID 9785 (Row 9785, Index Label: 9867): Extracted: 'health'
# ID 9786 (Row 9786, Index Label: 9868): Extracted: 'technology'
# ID 9787 (Row 9787, Index Label: 9869): Extracted: 'politics'
# ID 9788 (Row 9788, Index Label: 9870): Extracted: 'worldNews'
# ID 9789 (Row 9789, Index Label: 9871): Extracted: 'politics'
# ID 9790 (Row 9790, Index Label: 9872): Extracted: 'politics'
# ID 9791 (Row 9791, Index Label: 9873): Extracted: 'socialIssues'
# ID 9792 (Row 9792, Index Label: 9874): Extracted: 'politics'
# ID 9793 (Row 9793, Index Label: 9875): Extracted: 'worldNews'
# WARN: Rate limit hit for Article ID 9794 (Row 9794, Index Label: 9876). Attempt 1/7. Waiting 19.4s (consecutive rate limits: 1)...
# ID 9794 (Row 9794, Index Label: 9876): Extracted: ''socialIssues''
# ID 9795 (Row 9795, Index Label: 9877): Extracted: 'legal'
# ID 9796 (Row 9796, Index Label: 9878): Extracted: 'politics'
# ID 9797 (Row 9797, Index Label: 9879): Extracted: 'technology'
# ID 9798 (Row 9798, Index Label: 9880): Extracted: 'politics'
# ID 9799 (Row 9799, Index Label: 9881): Extracted: 'worldNews'
# ID 9800 (Row 9800, Index Label: 9882): Extracted: 'government'
# ID 9801 (Row 9801, Index Label: 9883): Extracted: 'politics'
# ID 9802 (Row 9802, Index Label: 9884): Extracted: 'socialIssues'
#
# Processing item 2701/2898 in current range (ID: 9803)...
# ID 9803 (Row 9803, Index Label: 9885): Extracted: 'worldNews'
# ID 9804 (Row 9804, Index Label: 9886): Extracted: 'politics'
# ID 9805 (Row 9805, Index Label: 9887): Extracted: 'worldNews'
# ID 9806 (Row 9806, Index Label: 9888): Extracted: 'worldNews'
# ID 9807 (Row 9807, Index Label: 9889): Extracted: 'politics'
# ID 9808 (Row 9808, Index Label: 9890): Extracted: 'government'
# ID 9809 (Row 9809, Index Label: 9891): Extracted: 'politics'
# ID 9810 (Row 9810, Index Label: 9892): Extracted: 'politics'
# ID 9811 (Row 9811, Index Label: 9893): Extracted: 'politics'
# ID 9812 (Row 9812, Index Label: 9894): Extracted: 'politics'
# ID 9813 (Row 9813, Index Label: 9895): Extracted: 'politics'
# ID 9814 (Row 9814, Index Label: 9896): Extracted: 'worldNews'
# ID 9815 (Row 9815, Index Label: 9897): Extracted: 'worldNews'
# ID 9816 (Row 9816, Index Label: 9898): Extracted: 'politics'
# ID 9817 (Row 9817, Index Label: 9899): Extracted: 'politics'
# ID 9818 (Row 9818, Index Label: 9900): Extracted: 'worldNews'
# ID 9819 (Row 9819, Index Label: 9901): Extracted: 'politics'
# ID 9820 (Row 9820, Index Label: 9902): Extracted: 'legal'
# ID 9821 (Row 9821, Index Label: 9903): Extracted: 'politics'
# ID 9822 (Row 9822, Index Label: 9904): Extracted: 'politics'
# ID 9823 (Row 9823, Index Label: 9905): Extracted: 'politics'
# ID 9824 (Row 9824, Index Label: 9906): Extracted: 'politics'
# ID 9825 (Row 9825, Index Label: 9907): Extracted: 'government'
# ID 9826 (Row 9826, Index Label: 9908): Extracted: 'politics'
# ID 9827 (Row 9827, Index Label: 9909): Extracted: 'politics'
# ID 9828 (Row 9828, Index Label: 9910): Extracted: 'legal'
# ID 9829 (Row 9829, Index Label: 9911): Extracted: 'usNews'
# ID 9830 (Row 9830, Index Label: 9912): Extracted: 'politics'
# ID 9831 (Row 9831, Index Label: 9913): Extracted: 'politics'
# ID 9832 (Row 9832, Index Label: 9914): Extracted: 'politics'
# ID 9833 (Row 9833, Index Label: 9915): Extracted: 'politics'
# ID 9834 (Row 9834, Index Label: 9916): Extracted: 'politics'
# ID 9835 (Row 9835, Index Label: 9917): Extracted: 'government'
# ID 9836 (Row 9836, Index Label: 9918): Extracted: 'socialIssues'
# ID 9837 (Row 9837, Index Label: 9919): Extracted: 'socialIssues'
# ID 9838 (Row 9838, Index Label: 9920): Extracted: 'politics'
# ID 9839 (Row 9839, Index Label: 9921): Extracted: 'middleEastNews'
# ID 9840 (Row 9840, Index Label: 9922): Extracted: 'politics'
# ID 9841 (Row 9841, Index Label: 9923): Extracted: 'politics'
# ID 9842 (Row 9842, Index Label: 9924): Extracted: 'politics'
# ID 9843 (Row 9843, Index Label: 9925): Extracted: 'business'
# ID 9844 (Row 9844, Index Label: 9926): Extracted: 'politics'
# ID 9845 (Row 9845, Index Label: 9927): Extracted: 'politics'
# ID 9846 (Row 9846, Index Label: 9928): Extracted: 'politics'
# ID 9847 (Row 9847, Index Label: 9929): Extracted: 'politics'
# ID 9848 (Row 9848, Index Label: 9930): Extracted: 'politics'
# ID 9849 (Row 9849, Index Label: 9931): Extracted: 'politics'
# ID 9850 (Row 9850, Index Label: 9932): Extracted: 'technology'
# ID 9851 (Row 9851, Index Label: 9933): Extracted: 'technology'
# ID 9852 (Row 9852, Index Label: 9934): Extracted: 'government'
# ID 9853 (Row 9853, Index Label: 9935): Extracted: 'environment'
# ID 9854 (Row 9854, Index Label: 9936): Extracted: 'entertainment'
# ID 9855 (Row 9855, Index Label: 9937): Extracted: 'politics'
# ID 9856 (Row 9856, Index Label: 9938): Extracted: 'politics'
# ID 9857 (Row 9857, Index Label: 9939): Extracted: 'politics'
# ID 9858 (Row 9858, Index Label: 9940): Extracted: 'politics'
# ID 9859 (Row 9859, Index Label: 9941): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 9860 (Row 9860, Index Label: 9942). Attempt 1/7. Waiting 20.3s (consecutive rate limits: 1)...
# ID 9860 (Row 9860, Index Label: 9942): Extracted: 'politics'
# ID 9861 (Row 9861, Index Label: 9943): Extracted: 'politics'
# ID 9862 (Row 9862, Index Label: 9944): Extracted: 'politics'
# ID 9863 (Row 9863, Index Label: 9945): Extracted: 'technology'
# ID 9864 (Row 9864, Index Label: 9946): Extracted: 'politics'
# ID 9865 (Row 9865, Index Label: 9947): Extracted: 'politics'
# ID 9866 (Row 9866, Index Label: 9948): Extracted: 'politics'
# ID 9867 (Row 9867, Index Label: 9949): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 9868 (Row 9868, Index Label: 9950). Attempt 1/7. Waiting 20.2s (consecutive rate limits: 1)...
# ID 9868 (Row 9868, Index Label: 9950): Extracted: 'finance'
# ID 9869 (Row 9869, Index Label: 9951): Extracted: 'business'
# ID 9870 (Row 9870, Index Label: 9952): Extracted: 'technology'
# ID 9871 (Row 9871, Index Label: 9953): Extracted: 'government'
# ID 9872 (Row 9872, Index Label: 9954): Extracted: 'politics'
# ID 9873 (Row 9873, Index Label: 9955): Extracted: 'politics'
# ID 9874 (Row 9874, Index Label: 9956): Extracted: ''socialIssues''
# ID 9875 (Row 9875, Index Label: 9957): Extracted: 'government'
# WARN: Rate limit hit for Article ID 9876 (Row 9876, Index Label: 9958). Attempt 1/7. Waiting 19.5s (consecutive rate limits: 1)...
# ID 9876 (Row 9876, Index Label: 9958): Extracted: 'technology'
# ID 9877 (Row 9877, Index Label: 9959): Extracted: 'health'
# ID 9878 (Row 9878, Index Label: 9960): Extracted: 'business'
# ID 9879 (Row 9879, Index Label: 9961): Extracted: 'politics'
# ID 9880 (Row 9880, Index Label: 9962): Extracted: 'politics'
# ID 9881 (Row 9881, Index Label: 9963): Extracted: 'politics'
# ID 9882 (Row 9882, Index Label: 9964): Extracted: 'politics'
# ID 9883 (Row 9883, Index Label: 9965): Extracted: 'politics'
# ID 9884 (Row 9884, Index Label: 9966): Extracted: 'politics'
# ID 9885 (Row 9885, Index Label: 9967): Extracted: 'politics'
# ID 9886 (Row 9886, Index Label: 9968): Extracted: 'politics'
# ID 9887 (Row 9887, Index Label: 9969): Extracted: 'health'
# ID 9888 (Row 9888, Index Label: 9970): Extracted: 'health'
# ID 9889 (Row 9889, Index Label: 9971): Extracted: 'socialIssues'
# ID 9890 (Row 9890, Index Label: 9972): Extracted: 'politics'
# ID 9891 (Row 9891, Index Label: 9973): Extracted: 'politics'
# ID 9892 (Row 9892, Index Label: 9974): Extracted: 'politics'
# ID 9893 (Row 9893, Index Label: 9975): Extracted: 'finance'
# ID 9894 (Row 9894, Index Label: 9976): Extracted: 'politics'
# ID 9895 (Row 9895, Index Label: 9977): Extracted: 'politics'
# ID 9896 (Row 9896, Index Label: 9978): Extracted: 'politics'
# ID 9897 (Row 9897, Index Label: 9979): Extracted: 'politics'
# ID 9898 (Row 9898, Index Label: 9980): Extracted: 'politics'
# ID 9899 (Row 9899, Index Label: 9981): Extracted: 'politics'
# ID 9900 (Row 9900, Index Label: 9982): Extracted: 'politics'
# ID 9901 (Row 9901, Index Label: 9983): Extracted: 'socialIssues'
# ID 9902 (Row 9902, Index Label: 9984): Extracted: 'politics'
#
# Processing item 2801/2898 in current range (ID: 9903)...
# ID 9903 (Row 9903, Index Label: 9985): Extracted: 'socialIssues'
# ID 9904 (Row 9904, Index Label: 9986): Extracted: 'politics'
# ID 9905 (Row 9905, Index Label: 9987): Extracted: 'finance'
# WARN: Rate limit hit for Article ID 9906 (Row 9906, Index Label: 9988). Attempt 1/7. Waiting 20.3s (consecutive rate limits: 1)...
# ID 9906 (Row 9906, Index Label: 9988): Extracted: 'socialIssues'
# ID 9907 (Row 9907, Index Label: 9989): Extracted: 'government'
# ID 9908 (Row 9908, Index Label: 9990): Extracted: 'government'
# ID 9909 (Row 9909, Index Label: 9991): Extracted: 'crime'
# ID 9910 (Row 9910, Index Label: 9992): Extracted: 'politics'
# ID 9911 (Row 9911, Index Label: 9993): Extracted: 'politics'
# ID 9912 (Row 9912, Index Label: 9994): Extracted: 'politics'
# ID 9913 (Row 9913, Index Label: 9995): Extracted: 'politics'
# ID 9914 (Row 9914, Index Label: 9996): Extracted: 'finance'
# ID 9915 (Row 9915, Index Label: 9997): Extracted: 'politics'
# ID 9916 (Row 9916, Index Label: 9998): Extracted: 'politics'
# ID 9917 (Row 9917, Index Label: 9999): Extracted: 'crime'
# ID 9918 (Row 9918, Index Label: 10000): Extracted: 'politics'
# ID 9919 (Row 9919, Index Label: 10001): Extracted: 'politics'
# ID 9920 (Row 9920, Index Label: 10002): Extracted: 'politics'
# ID 9921 (Row 9921, Index Label: 10003): Extracted: 'crime'
# ID 9922 (Row 9922, Index Label: 10004): Extracted: 'politics'
# ID 9923 (Row 9923, Index Label: 10005): Extracted: 'politics'
# ID 9924 (Row 9924, Index Label: 10006): Extracted: 'socialIssues'
# ID 9925 (Row 9925, Index Label: 10007): Extracted: 'technology'
# ID 9926 (Row 9926, Index Label: 10008): Extracted: 'politics'
# ID 9927 (Row 9927, Index Label: 10009): Extracted: 'socialIssues'
# ID 9928 (Row 9928, Index Label: 10010): Extracted: 'worldNews'
# ID 9929 (Row 9929, Index Label: 10011): Extracted: 'politics'
# ID 9930 (Row 9930, Index Label: 10012): Extracted: 'politics'
# ID 9931 (Row 9931, Index Label: 10013): Extracted: 'technology'
# ID 9932 (Row 9932, Index Label: 10014): Extracted: 'politics'
# ID 9933 (Row 9933, Index Label: 10015): Extracted: 'politics'
# ID 9934 (Row 9934, Index Label: 10016): Extracted: 'socialIssues'
# WARN: Rate limit hit for Article ID 9935 (Row 9935, Index Label: 10017). Attempt 1/7. Waiting 19.5s (consecutive rate limits: 1)...
# ID 9935 (Row 9935, Index Label: 10017): Extracted: 'politics'
# ID 9936 (Row 9936, Index Label: 10018): Extracted: 'politics'
# ID 9937 (Row 9937, Index Label: 10019): Extracted: 'politics'
# ID 9938 (Row 9938, Index Label: 10020): Extracted: 'politics'
# ID 9939 (Row 9939, Index Label: 10021): Extracted: 'politics'
# ID 9940 (Row 9940, Index Label: 10022): Extracted: 'politics'
# ID 9941 (Row 9941, Index Label: 10023): Extracted: 'politics'
# ID 9942 (Row 9942, Index Label: 10024): Extracted: 'politics'
# ID 9943 (Row 9943, Index Label: 10025): Extracted: 'politics'
# ID 9944 (Row 9944, Index Label: 10026): Extracted: 'business'
# ID 9945 (Row 9945, Index Label: 10027): Extracted: 'socialIssues'
# ID 9946 (Row 9946, Index Label: 10028): Extracted: 'socialIssues'
# ID 9947 (Row 9947, Index Label: 10029): Extracted: 'legal'
# ID 9948 (Row 9948, Index Label: 10030): Extracted: 'technology'
# ID 9949 (Row 9949, Index Label: 10031): Extracted: 'politics'
# ID 9950 (Row 9950, Index Label: 10032): Extracted: 'politics'
# ID 9951 (Row 9951, Index Label: 10033): Extracted: 'socialIssues'
# ID 9952 (Row 9952, Index Label: 10034): Extracted: 'worldNews'
# ID 9953 (Row 9953, Index Label: 10035): Extracted: 'politics'
# ID 9954 (Row 9954, Index Label: 10036): Extracted: 'politics'
# ID 9955 (Row 9955, Index Label: 10037): Extracted: 'government'
# ID 9956 (Row 9956, Index Label: 10038): Extracted: 'politics'
# ID 9957 (Row 9957, Index Label: 10039): Extracted: 'politics'
# ID 9958 (Row 9958, Index Label: 10040): Extracted: 'politics'
# ID 9959 (Row 9959, Index Label: 10041): Extracted: 'socialIssues'
# ID 9960 (Row 9960, Index Label: 10042): Extracted: 'politics'
# ID 9961 (Row 9961, Index Label: 10043): Extracted: 'finance'
# ID 9962 (Row 9962, Index Label: 10044): Extracted: 'legal'
# ID 9963 (Row 9963, Index Label: 10045): Extracted: 'politics'
# ID 9964 (Row 9964, Index Label: 10046): Extracted: 'socialIssues'
# ID 9965 (Row 9965, Index Label: 10047): Extracted: 'politics'
# WARN: Rate limit hit for Article ID 9966 (Row 9966, Index Label: 10048). Attempt 1/7. Waiting 20.0s (consecutive rate limits: 1)...
# ID 9966 (Row 9966, Index Label: 10048): Extracted: 'politics'
# ID 9967 (Row 9967, Index Label: 10049): Extracted: 'politics'
# ID 9968 (Row 9968, Index Label: 10050): Extracted: 'politics'
# ID 9969 (Row 9969, Index Label: 10051): Extracted: 'finance'
# ID 9970 (Row 9970, Index Label: 10052): Extracted: 'politics'
# ID 9971 (Row 9971, Index Label: 10053): Extracted: 'health'
# ID 9972 (Row 9972, Index Label: 10054): Extracted: 'finance'
# ID 9973 (Row 9973, Index Label: 10055): Extracted: 'finance'
# ID 9974 (Row 9974, Index Label: 10056): Extracted: 'finance'
# ID 9975 (Row 9975, Index Label: 10057): Extracted: 'politics'
# ID 9976 (Row 9976, Index Label: 10058): Extracted: 'finance'
# ID 9977 (Row 9977, Index Label: 10059): Extracted: 'politics'
# ID 9978 (Row 9978, Index Label: 10060): Extracted: 'politics'
# ID 9979 (Row 9979, Index Label: 10061): Extracted: 'finance'
# ID 9980 (Row 9980, Index Label: 10062): Extracted: 'politics'
# ID 9981 (Row 9981, Index Label: 10063): Extracted: 'government'
# ID 9982 (Row 9982, Index Label: 10064): Extracted: 'politics'
# ID 9983 (Row 9983, Index Label: 10065): Extracted: 'politics'
# ID 9984 (Row 9984, Index Label: 10066): Extracted: 'politics'
# ID 9985 (Row 9985, Index Label: 10067): Extracted: 'politics'
# ID 9986 (Row 9986, Index Label: 10068): Extracted: 'government'
# ID 9987 (Row 9987, Index Label: 10069): Extracted: 'crime'
# ID 9988 (Row 9988, Index Label: 10070): Extracted: 'finance'
# ID 9989 (Row 9989, Index Label: 10071): Extracted: 'politics'
# ID 9990 (Row 9990, Index Label: 10072): Extracted: 'politics'
# ID 9991 (Row 9991, Index Label: 10073): Extracted: 'politics'
# ID 9992 (Row 9992, Index Label: 10074): Extracted: 'politics'
# ID 9993 (Row 9993, Index Label: 10075): Extracted: 'politics'
# ID 9994 (Row 9994, Index Label: 10076): Extracted: 'legal'
# WARN: Rate limit hit for Article ID 9995 (Row 9995, Index Label: 10077). Attempt 1/7. Waiting 20.7s (consecutive rate limits: 1)...
# ID 9995 (Row 9995, Index Label: 10077): Extracted: 'health'
# ID 9996 (Row 9996, Index Label: 10078): Extracted: 'politics'
# ID 9997 (Row 9997, Index Label: 10079): Extracted: 'government'
# ID 9998 (Row 9998, Index Label: 10080): Extracted: 'education'
# ID 9999 (Row 9999, Index Label: 10081): Extracted: 'finance'
# ID 10000 (Row 10000, Index Label: 10082): Extracted: 'government'
#
# --- Processing for ID range 7103-10000 COMPLETED_RANGE. ---
# 2898 rows attempted in this range. Results saved to 'subjects_id_7103_to_10000.csv'
# CSV file contains columns: ['id', 'subject_category']
# ID range in saved file: 7103 to 10000
#
# --- Script Finished ---

# %%
# !gdown --id 12YdHCYSO5Jj-smZIW0bVN2WHBHwOamR2 -O subjects_for_dataset.zip
# !unzip subjects_for_dataset.zip
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=12YdHCYSO5Jj-smZIW0bVN2WHBHwOamR2
# To: /content/subjects_for_dataset.zip
# 100% 168k/168k [00:00<00:00, 69.2MB/s]
# Archive:  subjects_for_dataset.zip
#    creating: subjects_for_dataset/
#   inflating: subjects_for_dataset/subjects_id_10001_to_20000.csv
#   inflating: subjects_for_dataset/subjects_id_1_to_10000.csv
#   inflating: subjects_for_dataset/subjects_id_20001_to_25000.csv
#   inflating: subjects_for_dataset/subjects_id_25001_to_35000.csv
#   inflating: subjects_for_dataset/subjects_id_35001_to_45000.csv
#   inflating: subjects_for_dataset/subjects_id_45001_to_50000.csv
#   inflating: subjects_for_dataset/subjects_id_50001_to_53000.csv
#   inflating: subjects_for_dataset/subjects_id_53001_to_56000.csv
#   inflating: subjects_for_dataset/subjects_id_56001_to_60000.csv
#   inflating: subjects_for_dataset/subjects_id_60001_to_68604.csv

# %%
import os
import glob
import re
import csv

SOURCE_DIRECTORY = "/content/subjects_for_dataset"
FILE_PATTERN = "subjects_id_*.csv"
OUTPUT_FILE = "concatenated_subjects.csv"

FILENAME_REGEX = r"subjects_id_(\d+)_to_(\d+)\.csv"

def get_start_id_from_filename(filename):
    """Trích xuất ID bắt đầu từ tên file."""
    match = re.search(FILENAME_REGEX, os.path.basename(filename))
    if match:
        return int(match.group(1))
    return float('inf')

def main():
    full_pattern_path = os.path.join(SOURCE_DIRECTORY, FILE_PATTERN)
    csv_files = glob.glob(full_pattern_path)

    if not csv_files:
        print(f"Không tìm thấy file CSV nào trong thư mục '{SOURCE_DIRECTORY}' khớp với mẫu '{FILE_PATTERN}'.")
        return

    csv_files.sort(key=get_start_id_from_filename)

    print(f"Tìm thấy {len(csv_files)} file để nối:")
    for f_path in csv_files:
        print(f"  - {os.path.basename(f_path)}")

    header_written = False

    with open(OUTPUT_FILE, 'w', newline='', encoding='utf-8') as outfile:
        csv_writer = csv.writer(outfile)

        for i, filepath in enumerate(csv_files):
            try:
                with open(filepath, 'r', newline='', encoding='utf-8') as infile:
                    csv_reader = csv.reader(infile)

                    header = next(csv_reader)

                    if not header_written:
                        csv_writer.writerow(header)
                        header_written = True

                    for row in csv_reader:
                        csv_writer.writerow(row)
                print(f"Đã xử lý: {os.path.basename(filepath)}")
            except StopIteration:
                print(f"Cảnh báo: File {os.path.basename(filepath)} trống hoặc chỉ chứa tiêu đề. Bỏ qua phần thân file.")
            except Exception as e:
                print(f"Lỗi khi xử lý file {os.path.basename(filepath)}: {e}")

    if header_written:
        print(f"\nĐã nối thành công {len(csv_files)} file vào '{OUTPUT_FILE}'.")
    else:
        print(f"\nKhông có dữ liệu nào được ghi vào '{OUTPUT_FILE}'. Vui lòng kiểm tra các file đầu vào của bạn.")

if __name__ == "__main__":
    main()
# Out:
# Tìm thấy 10 file để nối:
#   - subjects_id_1_to_10000.csv
#   - subjects_id_10001_to_20000.csv
#   - subjects_id_20001_to_25000.csv
#   - subjects_id_25001_to_35000.csv
#   - subjects_id_35001_to_45000.csv
#   - subjects_id_45001_to_50000.csv
#   - subjects_id_50001_to_53000.csv
#   - subjects_id_53001_to_56000.csv
#   - subjects_id_56001_to_60000.csv
#   - subjects_id_60001_to_68604.csv
# Đã xử lý: subjects_id_1_to_10000.csv
# Đã xử lý: subjects_id_10001_to_20000.csv
# Đã xử lý: subjects_id_20001_to_25000.csv
# Đã xử lý: subjects_id_25001_to_35000.csv
# Đã xử lý: subjects_id_35001_to_45000.csv
# Đã xử lý: subjects_id_45001_to_50000.csv
# Đã xử lý: subjects_id_50001_to_53000.csv
# Đã xử lý: subjects_id_53001_to_56000.csv
# Đã xử lý: subjects_id_56001_to_60000.csv
# Đã xử lý: subjects_id_60001_to_68604.csv
#
# Đã nối thành công 10 file vào 'concatenated_subjects.csv'.

# %%
subjects = pd.read_csv("/content/concatenated_subjects.csv")
subjects.head()
# Out:
#    id subject_category
# 0   1         politics
# 1   2     socialIssues
# 2   3         politics
# 3   4         politics
# 4   5         business
